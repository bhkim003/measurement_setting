# %% [markdown]
# ## config 설정 및 weight 초기화

# %%
import os
import torch
import random
import numpy as np
import matplotlib.pyplot
from bh_utils import *

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"





my_seed = 0
# weight_file_path = r"net_save\save_now_net_weights_20260112_121819_873.pth"
weight_file_path = None

# HYPER_DATASET = 'DVS_GESTURE'
HYPER_DATASET = 'N_MNIST'
# HYPER_DATASET = 'NTIDIGITS_TARGET_0'
# HYPER_DATASET = 'NTIDIGITS_TARGET_1'
# HYPER_DATASET = 'NTIDIGITS_TARGET_2'
# HYPER_DATASET = 'NTIDIGITS_TARGET_3'
# HYPER_DATASET = 'NTIDIGITS_TARGET_4'
# HYPER_DATASET = 'NTIDIGITS_TARGET_5'
# HYPER_DATASET = 'NTIDIGITS_TARGET_6'
# HYPER_DATASET = 'NTIDIGITS_TARGET_7'
# HYPER_DATASET = 'NTIDIGITS_TARGET_8'
# HYPER_DATASET = 'NTIDIGITS_TARGET_9'

if HYPER_DATASET == 'DVS_GESTURE':
    topN_at_gesture = 4
    assert topN_at_gesture in [0,4,12]
    p_config = { # Trigger는 다시 당겨지고..
        "asic_mode":                      {"trigger": 1,  "value": 0}, #안쓸듯?  # 0 training_only, 1 train_inf_sweep, 2 inference_only
        "training_epochs":                {"trigger": 2,  "value": 200}, #안쓸듯?
        "inference_epochs":               {"trigger": 3,  "value": 200}, #안쓸듯?
        "dataset":                        {"trigger": 4,  "value": 0},   # 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
        "timesteps":                      {"trigger": 5,  "value": 10},
        "input_size_layer1":              {"trigger": 6,  "value": 980}, # DVS_GESTURE 980, N_MNIST 578, NTIDIGITS 512
        "long_time_input_streaming_mode": {"trigger": 7,  "value": 1},
        "binary_classifier_mode":         {"trigger": 8,  "value": 0},
        "loser_encourage_mode":           {"trigger": 9,  "value": 0}, # 1 true 0 false
        "layer1_cut_list":                {"trigger": 10, "value": layer_cut_generator(threshold = 128.0, sg_width = 4.0 * 2, learning_rate = 1.0, verbose = False)},
        "layer2_cut_list":                {"trigger": 11, "value": layer_cut_generator(threshold = 128.0, sg_width = 4.0 * 2, learning_rate = 1.0, verbose = False)},
    }
elif HYPER_DATASET == 'N_MNIST':
    p_config = { # Trigger는 다시 당겨지고..
        "asic_mode":                      {"trigger": 1,  "value": 0}, #안쓸듯?   # 0 training_only, 1 train_inf_sweep, 2 inference_only
        "training_epochs":                {"trigger": 2,  "value": 200}, #안쓸듯?
        "inference_epochs":               {"trigger": 3,  "value": 200}, #안쓸듯?
        "dataset":                        {"trigger": 4,  "value": 1},   # 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
        "timesteps":                      {"trigger": 5,  "value": 5},
        "input_size_layer1":              {"trigger": 6,  "value": 578}, # DVS_GESTURE 980, N_MNIST 578, NTIDIGITS 512
        "long_time_input_streaming_mode": {"trigger": 7,  "value": 0},
        "binary_classifier_mode":         {"trigger": 8,  "value": 0},
        "loser_encourage_mode":           {"trigger": 9,  "value": 0}, # 1 true 0 false
        "layer1_cut_list":                {"trigger": 10, "value": layer_cut_generator(threshold = 256.0, sg_width = 10.0 * 2, learning_rate = 2.0, verbose = False)},
        "layer2_cut_list":                {"trigger": 11, "value": layer_cut_generator(threshold = 256.0, sg_width = 10.0 * 2, learning_rate = 2.0, verbose = False)},
    }
elif HYPER_DATASET == 'NTIDIGITS_TARGET_0':
    target_word_at_ntidigits = 0
    p_config = { # Trigger는 다시 당겨지고..
        "asic_mode":                      {"trigger": 1,  "value": 0}, #안쓸듯?   # 0 training_only, 1 train_inf_sweep, 2 inference_only
        "training_epochs":                {"trigger": 2,  "value": 200}, #안쓸듯?
        "inference_epochs":               {"trigger": 3,  "value": 200}, #안쓸듯?
        "dataset":                        {"trigger": 4,  "value": 2},   # 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
        "timesteps":                      {"trigger": 5,  "value": 8},
        "input_size_layer1":              {"trigger": 6,  "value": 512}, # DVS_GESTURE 980, N_MNIST 578, NTIDIGITS 512
        "long_time_input_streaming_mode": {"trigger": 7,  "value": 0},
        "binary_classifier_mode":         {"trigger": 8,  "value": 1},
        "loser_encourage_mode":           {"trigger": 9,  "value": 1}, # 1 true 0 false
        "layer1_cut_list":                {"trigger": 10, "value": layer_cut_generator(threshold = 256.0, sg_width = 3.75, learning_rate = 1.0, verbose = False)},
        "layer2_cut_list":                {"trigger": 11, "value": layer_cut_generator(threshold = 256.0, sg_width = 3.75, learning_rate = 1.0, verbose = False)},
    }
elif HYPER_DATASET == 'NTIDIGITS_TARGET_1':
    target_word_at_ntidigits = 1
    p_config = { # Trigger는 다시 당겨지고..
        "asic_mode":                      {"trigger": 1,  "value": 0}, #안쓸듯?   # 0 training_only, 1 train_inf_sweep, 2 inference_only
        "training_epochs":                {"trigger": 2,  "value": 200}, #안쓸듯?
        "inference_epochs":               {"trigger": 3,  "value": 200}, #안쓸듯?
        "dataset":                        {"trigger": 4,  "value": 2},   # 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
        "timesteps":                      {"trigger": 5,  "value": 8},
        "input_size_layer1":              {"trigger": 6,  "value": 512}, # DVS_GESTURE 980, N_MNIST 578, NTIDIGITS 512
        "long_time_input_streaming_mode": {"trigger": 7,  "value": 0},
        "binary_classifier_mode":         {"trigger": 8,  "value": 1},
        "loser_encourage_mode":           {"trigger": 9,  "value": 1}, # 1 true 0 false
        "layer1_cut_list":                {"trigger": 10, "value": layer_cut_generator(threshold = 128.0, sg_width = 1.0, learning_rate = 1.0, verbose = False)},
        "layer2_cut_list":                {"trigger": 11, "value": layer_cut_generator(threshold = 128.0, sg_width = 1.0, learning_rate = 1.0, verbose = False)},
    }
elif HYPER_DATASET == 'NTIDIGITS_TARGET_2':
    target_word_at_ntidigits = 2
    p_config = { # Trigger는 다시 당겨지고..
        "asic_mode":                      {"trigger": 1,  "value": 0}, #안쓸듯?   # 0 training_only, 1 train_inf_sweep, 2 inference_only
        "training_epochs":                {"trigger": 2,  "value": 200}, #안쓸듯?
        "inference_epochs":               {"trigger": 3,  "value": 200}, #안쓸듯?
        "dataset":                        {"trigger": 4,  "value": 2},   # 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
        "timesteps":                      {"trigger": 5,  "value": 8},
        "input_size_layer1":              {"trigger": 6,  "value": 512}, # DVS_GESTURE 980, N_MNIST 578, NTIDIGITS 512
        "long_time_input_streaming_mode": {"trigger": 7,  "value": 0},
        "binary_classifier_mode":         {"trigger": 8,  "value": 1},
        "loser_encourage_mode":           {"trigger": 9,  "value": 1}, # 1 true 0 false
        "layer1_cut_list":                {"trigger": 10, "value": layer_cut_generator(threshold = 2048.0, sg_width = 1.0, learning_rate = 1.0, verbose = False)},
        "layer2_cut_list":                {"trigger": 11, "value": layer_cut_generator(threshold = 1024.0, sg_width = 8.0, learning_rate = 1.0, verbose = False)},
    }
elif HYPER_DATASET == 'NTIDIGITS_TARGET_3':
    target_word_at_ntidigits = 3
    p_config = { # Trigger는 다시 당겨지고..
        "asic_mode":                      {"trigger": 1,  "value": 0}, #안쓸듯?   # 0 training_only, 1 train_inf_sweep, 2 inference_only
        "training_epochs":                {"trigger": 2,  "value": 200}, #안쓸듯?
        "inference_epochs":               {"trigger": 3,  "value": 200}, #안쓸듯?
        "dataset":                        {"trigger": 4,  "value": 2},   # 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
        "timesteps":                      {"trigger": 5,  "value": 8},
        "input_size_layer1":              {"trigger": 6,  "value": 512}, # DVS_GESTURE 980, N_MNIST 578, NTIDIGITS 512
        "long_time_input_streaming_mode": {"trigger": 7,  "value": 0},
        "binary_classifier_mode":         {"trigger": 8,  "value": 1},
        "loser_encourage_mode":           {"trigger": 9,  "value": 1}, # 1 true 0 false
        "layer1_cut_list":                {"trigger": 10, "value": layer_cut_generator(threshold = 512.0, sg_width = 1.0, learning_rate = 1.0, verbose = False)},
        "layer2_cut_list":                {"trigger": 11, "value": layer_cut_generator(threshold = 512.0, sg_width = 1.0, learning_rate = 1.0, verbose = False)},
    }
elif HYPER_DATASET == 'NTIDIGITS_TARGET_4':
    target_word_at_ntidigits = 4
    p_config = { # Trigger는 다시 당겨지고..
        "asic_mode":                      {"trigger": 1,  "value": 0}, #안쓸듯?   # 0 training_only, 1 train_inf_sweep, 2 inference_only
        "training_epochs":                {"trigger": 2,  "value": 200}, #안쓸듯?
        "inference_epochs":               {"trigger": 3,  "value": 200}, #안쓸듯?
        "dataset":                        {"trigger": 4,  "value": 2},   # 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
        "timesteps":                      {"trigger": 5,  "value": 8},
        "input_size_layer1":              {"trigger": 6,  "value": 512}, # DVS_GESTURE 980, N_MNIST 578, NTIDIGITS 512
        "long_time_input_streaming_mode": {"trigger": 7,  "value": 0},
        "binary_classifier_mode":         {"trigger": 8,  "value": 1},
        "loser_encourage_mode":           {"trigger": 9,  "value": 1}, # 1 true 0 false
        "layer1_cut_list":                {"trigger": 10, "value": layer_cut_generator(threshold = 1024.0, sg_width = 1.0, learning_rate = 1.0, verbose = False)},
        "layer2_cut_list":                {"trigger": 11, "value": layer_cut_generator(threshold = 1024.0, sg_width = 1.0, learning_rate = 1.0, verbose = False)},
    }
elif HYPER_DATASET == 'NTIDIGITS_TARGET_5':
    target_word_at_ntidigits = 5
    p_config = { # Trigger는 다시 당겨지고..
        "asic_mode":                      {"trigger": 1,  "value": 0}, #안쓸듯?   # 0 training_only, 1 train_inf_sweep, 2 inference_only
        "training_epochs":                {"trigger": 2,  "value": 200}, #안쓸듯?
        "inference_epochs":               {"trigger": 3,  "value": 200}, #안쓸듯?
        "dataset":                        {"trigger": 4,  "value": 2},   # 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
        "timesteps":                      {"trigger": 5,  "value": 8},
        "input_size_layer1":              {"trigger": 6,  "value": 512}, # DVS_GESTURE 980, N_MNIST 578, NTIDIGITS 512
        "long_time_input_streaming_mode": {"trigger": 7,  "value": 0},
        "binary_classifier_mode":         {"trigger": 8,  "value": 1},
        "loser_encourage_mode":           {"trigger": 9,  "value": 1}, # 1 true 0 false
        "layer1_cut_list":                {"trigger": 10, "value": layer_cut_generator(threshold = 1024.0, sg_width = 4.0, learning_rate = 2.0, verbose = False)},
        "layer2_cut_list":                {"trigger": 11, "value": layer_cut_generator(threshold = 256.0, sg_width = 32.0, learning_rate = 2.0, verbose = False)},
    }
elif HYPER_DATASET == 'NTIDIGITS_TARGET_6':
    target_word_at_ntidigits = 6
    p_config = { # Trigger는 다시 당겨지고..
        "asic_mode":                      {"trigger": 1,  "value": 0}, #안쓸듯?   # 0 training_only, 1 train_inf_sweep, 2 inference_only
        "training_epochs":                {"trigger": 2,  "value": 200}, #안쓸듯?
        "inference_epochs":               {"trigger": 3,  "value": 200}, #안쓸듯?
        "dataset":                        {"trigger": 4,  "value": 2},   # 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
        "timesteps":                      {"trigger": 5,  "value": 8},
        "input_size_layer1":              {"trigger": 6,  "value": 512}, # DVS_GESTURE 980, N_MNIST 578, NTIDIGITS 512
        "long_time_input_streaming_mode": {"trigger": 7,  "value": 0},
        "binary_classifier_mode":         {"trigger": 8,  "value": 1},
        "loser_encourage_mode":           {"trigger": 9,  "value": 1}, # 1 true 0 false
        "layer1_cut_list":                {"trigger": 10, "value": layer_cut_generator(threshold = 1024.0, sg_width = 2.5, learning_rate = 2.0, verbose = False)},
        "layer2_cut_list":                {"trigger": 11, "value": layer_cut_generator(threshold = 1024.0, sg_width = 2.5, learning_rate = 2.0, verbose = False)},
    }
elif HYPER_DATASET == 'NTIDIGITS_TARGET_7':
    target_word_at_ntidigits = 7
    p_config = { # Trigger는 다시 당겨지고..
        "asic_mode":                      {"trigger": 1,  "value": 0}, #안쓸듯?   # 0 training_only, 1 train_inf_sweep, 2 inference_only
        "training_epochs":                {"trigger": 2,  "value": 200}, #안쓸듯?
        "inference_epochs":               {"trigger": 3,  "value": 200}, #안쓸듯?
        "dataset":                        {"trigger": 4,  "value": 2},   # 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
        "timesteps":                      {"trigger": 5,  "value": 8},
        "input_size_layer1":              {"trigger": 6,  "value": 512}, # DVS_GESTURE 980, N_MNIST 578, NTIDIGITS 512
        "long_time_input_streaming_mode": {"trigger": 7,  "value": 0},
        "binary_classifier_mode":         {"trigger": 8,  "value": 1},
        "loser_encourage_mode":           {"trigger": 9,  "value": 1}, # 1 true 0 false
        "layer1_cut_list":                {"trigger": 10, "value": layer_cut_generator(threshold = 32.0, sg_width = 2.0, learning_rate = 1.0, verbose = False)},
        "layer2_cut_list":                {"trigger": 11, "value": layer_cut_generator(threshold = 256.0, sg_width = 4.0, learning_rate = 1.0, verbose = False)},
    }
elif HYPER_DATASET == 'NTIDIGITS_TARGET_8':
    target_word_at_ntidigits = 8
    p_config = { # Trigger는 다시 당겨지고..
        "asic_mode":                      {"trigger": 1,  "value": 0}, #안쓸듯?   # 0 training_only, 1 train_inf_sweep, 2 inference_only
        "training_epochs":                {"trigger": 2,  "value": 200}, #안쓸듯?
        "inference_epochs":               {"trigger": 3,  "value": 200}, #안쓸듯?
        "dataset":                        {"trigger": 4,  "value": 2},   # 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
        "timesteps":                      {"trigger": 5,  "value": 8},
        "input_size_layer1":              {"trigger": 6,  "value": 512}, # DVS_GESTURE 980, N_MNIST 578, NTIDIGITS 512
        "long_time_input_streaming_mode": {"trigger": 7,  "value": 0},
        "binary_classifier_mode":         {"trigger": 8,  "value": 1},
        "loser_encourage_mode":           {"trigger": 9,  "value": 1}, # 1 true 0 false
        "layer1_cut_list":                {"trigger": 10, "value": layer_cut_generator(threshold = 512.0, sg_width = 3.75, learning_rate = 2.0, verbose = False)},
        "layer2_cut_list":                {"trigger": 11, "value": layer_cut_generator(threshold = 512.0, sg_width = 3.75, learning_rate = 2.0, verbose = False)},
    }
elif HYPER_DATASET == 'NTIDIGITS_TARGET_9':
    target_word_at_ntidigits = 9
    p_config = { # Trigger는 다시 당겨지고..
        "asic_mode":                      {"trigger": 1,  "value": 0}, #안쓸듯?   # 0 training_only, 1 train_inf_sweep, 2 inference_only
        "training_epochs":                {"trigger": 2,  "value": 200}, #안쓸듯?
        "inference_epochs":               {"trigger": 3,  "value": 200}, #안쓸듯?
        "dataset":                        {"trigger": 4,  "value": 2},   # 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
        "timesteps":                      {"trigger": 5,  "value": 8},
        "input_size_layer1":              {"trigger": 6,  "value": 512}, # DVS_GESTURE 980, N_MNIST 578, NTIDIGITS 512
        "long_time_input_streaming_mode": {"trigger": 7,  "value": 0},
        "binary_classifier_mode":         {"trigger": 8,  "value": 1},
        "loser_encourage_mode":           {"trigger": 9,  "value": 1}, # 1 true 0 false
        "layer1_cut_list":                {"trigger": 10, "value": layer_cut_generator(threshold = 512.0, sg_width = 3.75, learning_rate = 2.0, verbose = False)},
        "layer2_cut_list":                {"trigger": 11, "value": layer_cut_generator(threshold = 512.0, sg_width = 3.75, learning_rate = 2.0, verbose = False)},
    }
else:
    assert False, "HYPER_DATASET 설정 필요"



if p_config["dataset"]["value"] == 0:
    dataset = 'DVS_GESTURE' # 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
elif p_config["dataset"]["value"] == 1:
    dataset = 'N_MNIST'
elif p_config["dataset"]["value"] == 2:
    dataset = 'NTIDIGITS'
else:
    assert False, "데이터셋 설정 필요"

# 32bit per address
dram_address_weight_start = 0 
dram_address_weight_last = 110_392



seed_assign(my_seed)
if dataset == 'DVS_GESTURE':
    input_size = p_config['input_size_layer1']['value']
    assert input_size == 980, "DVS_GESTURE input_size는 980이어야 합니다."
    init_scaling = [10000+ 9,10000+ 9,10000+ 8]
elif dataset == 'N_MNIST':
    input_size = p_config['input_size_layer1']['value']
    assert input_size == 578, "N_MNIST input_size는 578이어야 합니다."
    init_scaling = [10000+ 9,10000+ 9,10000+ 8]
elif dataset == 'NTIDIGITS':
    input_size = p_config['input_size_layer1']['value']
    assert input_size == 512, "NTIDIGITS input_size는 512이어야 합니다."
    init_scaling = [10000+ 12,10000+ 12,10000+ 11]
else:
    assert False, "데이터셋 설정 필요"  


layer1_sram_row = 980
layer1_sram_bank = 10
layer1_sram_bit = 160
layer2_sram_row = 200
layer2_sram_bank = 10
layer2_sram_bit = 160
layer3_sram_row = 200
layer3_sram_bank = 10
layer3_sram_bit = 8



if (weight_file_path is not None) :
    if not os.path.exists(weight_file_path):
        print("파일을 찾을 수 없습니다.")
    else:
        # 파일 로드
        # weights = torch.load(weight_file_path, map_location=torch.device('cpu'))
        weights = torch.load(weight_file_path, map_location=torch.device('cpu'), weights_only=True)
        # print(f"=== 'fc.weight' 필터링 결과 ===\n")
        # print(f"{'Layer Name':<40} | {'Shape'}")
        # print("-" * 60)

        if isinstance(weights, dict):
            for key, value in weights.items():
                if "module.layers.1.fc.weight" in key:
                    # weight_plot(value)
                    if dataset == 'DVS_GESTURE':
                        assert value.shape == (200,980), f"value.shape: {value.shape}"
                    elif dataset == 'N_MNIST':
                        assert value.shape == (200,578), f"value.shape: {value.shape}"
                    elif dataset == 'NTIDIGITS':
                        assert value.shape == (200,512), f"value.shape: {value.shape}"
                    else:
                        assert False, "데이터셋 설정 필요"  

                    layer1_weight = torch.nn.functional.pad(value, (0, layer1_sram_row - value.shape[1], 0, 0), "constant", 0)
                    # print(f"{key:<40} | {list(layer1_weight.shape)}")
                    # print(layer1_weight)
                if "module.layers.4.fc.weight" in key:
                    assert value.shape == (200,200), f"value.shape: {value.shape}"
                    # weight_plot(value)
                    layer2_weight = value
                    # print(f"{key:<40} | {list(layer2_weight.shape)}")
                    # print(layer2_weight)
                if "module.layers.7.fc.weight" in key:
                    assert value.shape == (10,200), f"value.shape: {value.shape}"
                    # weight_plot(value)
                    layer3_weight = value
                    # print(f"{key:<40} | {list(layer3_weight.shape)}")
                    # print(layer3_weight)
        else:
            print("딕셔너리 형태가 아닙니다.")


else:
    layer1_value = torch.nn.Linear(input_size, layer2_sram_row, bias=False)
    layer1_weight = layer1_value.weight.data * (2**(init_scaling[0]-10000) * 1.0) if init_scaling[0] >= 10000 else layer1_value.weight.data * (2**(init_scaling[0]) * 1.0)
    layer1_weight = quantize_tensor(layer1_weight)
    # weight_plot(layer1_weight)
    layer1_weight = torch.nn.functional.pad(layer1_weight, (0, layer1_sram_row - layer1_weight.shape[1], 0, 0), "constant", 0)
    # print(layer1_weight, layer1_weight.shape)


    layer2_value = torch.nn.Linear(layer2_sram_row, layer3_sram_row, bias=False)
    layer2_weight = layer2_value.weight.data * (2**(init_scaling[1]-10000) * 1.0) if init_scaling[0] >= 10000 else layer1_value.weight.data * (2**(init_scaling[0]) * 1.0)
    layer2_weight = quantize_tensor(layer2_weight)
    # weight_plot(layer2_weight)
    # print(layer2_weight, layer2_weight.shape)


    layer3_value = torch.nn.Linear(layer3_sram_row, 10, bias=False)
    layer3_weight = layer3_value.weight.data * (2**(init_scaling[2]-10000) * 1.0) if init_scaling[0] >= 10000 else layer1_value.weight.data * (2**(init_scaling[0]) * 1.0)
    layer3_weight = quantize_tensor(layer3_weight)
    # weight_plot(layer3_weight)
    # print(layer3_weight, layer3_weight.shape)

layer1_weight_np = layer1_weight.numpy().astype(np.int8)
layer2_weight_np = layer2_weight.numpy().astype(np.int8)
layer3_weight_np = layer3_weight.numpy().astype(np.int8)


# #zero init
# layer1_weight_np = layer1_weight_np*0.0
# layer2_weight_np = layer2_weight_np*0.0
# layer3_weight_np = layer3_weight_np*0.0


layer1_weight_np_t = layer1_weight_np.T

# 세로(axis=1) 방향으로 10등분
# 200열 / 10개 뱅크 = 각 뱅크당 20열
layer1_banks = np.split(layer1_weight_np_t, layer1_sram_bank, axis=1)
layer1_banks_renewal = np.split(layer1_weight_np_t.copy(), layer1_sram_bank, axis=1)
for i in range(layer1_banks[0].shape[0]):
    for j in range(len(layer1_banks)):
        idx1 = (j + (i%10))%10
        (layer1_banks_renewal[idx1])[i] = (layer1_banks[j])[i]

# axis=1(열 방향)로 10개의 뱅크를 다시 이어붙임
layer1_weight_reassembled = np.concatenate(layer1_banks_renewal, axis=1) # (980, 200)



layer2_weight_np_t = layer2_weight_np.T

layer2_banks = np.split(layer2_weight_np_t, layer2_sram_bank, axis=1)
layer2_banks_renewal = np.split(layer2_weight_np_t.copy(), layer2_sram_bank, axis=1)
for i in range(layer2_banks[0].shape[0]):
    for j in range(len(layer2_banks)):
        idx1 = (j + (i%10))%10
        (layer2_banks_renewal[idx1])[i] = (layer2_banks[j])[i]

layer2_weight_reassembled = np.concatenate(layer2_banks_renewal, axis=1) 


layer3_weight_np_t = layer3_weight_np.T

layer3_banks = np.split(layer3_weight_np_t, layer3_sram_bank, axis=1)
layer3_banks_renewal = np.split(layer3_weight_np_t.copy(), layer3_sram_bank, axis=1)
for i in range(layer3_banks[0].shape[0]):
    for j in range(len(layer3_banks)):
        idx1 = (j + (i%10))%10
        (layer3_banks_renewal[idx1])[i] = (layer3_banks[j])[i]

layer3_weight_reassembled = np.concatenate(layer3_banks_renewal, axis=1) 

# print(f'layer1_weight_reassembled shape: {layer1_weight_reassembled.shape}')
# print(f'layer2_weight_reassembled shape: {layer2_weight_reassembled.shape}')
# print(f'layer3_weight_reassembled shape: {layer3_weight_reassembled.shape}')


# 결과를 저장할 리스트 (또는 파일로 직접 저장 가능)
layer1_hex_outputs = []
for row in range(layer1_weight_reassembled.shape[0]):
    for bank in range(layer1_sram_bank):
        # 1. 현재 뱅크의 20바이트 추출
        one_dram_word = layer1_weight_reassembled[row, bank*20 : (bank+1)*20]
        
        # 2. 역순 정렬: [19][18]...[0] 순서로 hex 문자열 생성
        # 각 요소는 8bit이므로 2자리 hex(:02x)로 변환
        hex_160bit = "".join(f"{int(val) & 0xFF:02x}" for val in reversed(one_dram_word))
        
        # 3. 256bit가 되도록 상위에 96bit(hex 24자리) 0 패딩 추가
        # 256bit = 64 hex chars (160bit = 40 hex chars)
        padding_96bit = "0" * 24
        final_256bit_word = padding_96bit + hex_160bit
        
        layer1_hex_outputs.append(final_256bit_word)
    
# 결과를 저장할 리스트 (또는 파일로 직접 저장 가능)
layer2_hex_outputs = []
for row in range(layer2_weight_reassembled.shape[0]):
    for bank in range(layer2_sram_bank):
        # 1. 현재 뱅크의 20바이트 추출
        one_dram_word = layer2_weight_reassembled[row, bank*20 : (bank+1)*20]
        
        # 2. 역순 정렬: [19][18]...[0] 순서로 hex 문자열 생성
        # 각 요소는 8bit이므로 2자리 hex(:02x)로 변환
        hex_160bit = "".join(f"{int(val) & 0xFF:02x}" for val in reversed(one_dram_word))
        
        # 3. 256bit가 되도록 상위에 96bit(hex 24자리) 0 패딩 추가
        # 256bit = 64 hex chars (160bit = 40 hex chars)
        padding_96bit = "0" * 24
        final_256bit_word = padding_96bit + hex_160bit
        
        layer2_hex_outputs.append(final_256bit_word)
    
# 결과를 저장할 리스트 (또는 파일로 직접 저장 가능)
layer3_hex_outputs = []
for row in range(layer3_weight_reassembled.shape[0]):
    for bank in range(layer3_sram_bank):
        # 1. 현재 뱅크의 1바이트 추출
        one_dram_word = layer3_weight_reassembled[row, bank*1 : (bank+1)*1]
        
        # 2. 역순 정렬: [19][18]...[0] 순서로 hex 문자열 생성
        # 각 요소는 8bit이므로 2자리 hex(:02x)로 변환
        hex_8bit = "".join(f"{int(val) & 0xFF:02x}" for val in reversed(one_dram_word))
        
        # 3. 256bit가 되도록 상위에 248bit(hex 62자리) 0 패딩 추가
        # 256bit = 64 hex chars (248bit = 62 hex chars)
        padding_248bit = "0" * 62
        final_256bit_word = padding_248bit + hex_8bit
        
        layer3_hex_outputs.append(final_256bit_word)
# print(f'layer1_hex_outputs length: {len(layer1_hex_outputs)}')
# print(f'layer2_hex_outputs length: {len(layer2_hex_outputs)}')
# print(f'layer3_hex_outputs length: {len(layer3_hex_outputs)}')

total_hex_outputs = layer1_hex_outputs + layer2_hex_outputs + layer3_hex_outputs
# print(f'total_hex_outputs length: {len(total_hex_outputs)}')


# total_hex_outputs의 요소들을 역순으로 뒤집어서(reversed) 하나로 합칩니다.
# 결과물은 엄청나게 긴 하나의 Hex 문자열이 됩니다.
# total_long_hex_string = "".join(reversed(total_hex_outputs))
total_long_hex_string = "".join(total_hex_outputs)

# # 출력 확인 (너무 길 수 있으니 앞뒤 일부와 전체 길이만 확인)
# print(f"Total String Length (Hex chars): {len(total_long_hex_string)}")
# print(f"Total String Length (Bits): {len(total_long_hex_string) * 4}bit")
# print(f"Total String Length (Bytes): {len(total_long_hex_string) * 4 / 8:.3f}Byte")
# print(f"Total String Length (kBytes): {len(total_long_hex_string) * 4 / 8/ 1024:.3f}kByte")
# print(f"Total String Length (MBytes): {len(total_long_hex_string) * 4 / 8/ 1024/1024:.3f}MByte")
# print(f'DRAM Address Range: 0 to {len(total_long_hex_string) * 4 / 256 *8 - 8:.0f}')
print(f"\nWeight 약간보자")
print(f"Start (MSB side): {total_long_hex_string[:256]}...")
print(f"End (LSB side): ...{total_long_hex_string[-256:]}")

# total_long_hex_string을 하나의 긴 문자열로 그대로 저장합니다.
with open("init_weight.txt", "w") as f:
    f.write(total_long_hex_string)

print(f"✅ 파일 저장 완료: init_weight.txt")
print(f"총 Hex 글자 수: {len(total_long_hex_string):,}자")
print(f"파일 용량: {len(total_long_hex_string) / 2:,.0f}B")
print(f"파일 용량: {len(total_long_hex_string) / 2 / 1024 / 1024:.3f}MB")

# # # 1. 파일 다시 읽기
# with open("init_weight.txt", "r") as f:
#     loaded_hex_string = f.read()

# # 2. 원본 데이터와 비교
# is_identical = (total_long_hex_string == loaded_hex_string)

# # 3. 결과 출력
# print(f"=== 검증 결과 ===")
# print(f"원본 문자열 길이: {len(total_long_hex_string):,} 자")
# print(f"읽어온 문자열 길이: {len(loaded_hex_string):,} 자")
# print(f"데이터 일치 여부: {is_identical}")

# # 만약 다르다면 어느 부분이 다른지 체크 (데이터가 같으면 실행 안 됨)
# if not is_identical:
#     for i in range(min(len(total_long_hex_string), len(loaded_hex_string))):
#         if total_long_hex_string[i] != loaded_hex_string[i]:
#             print(f"최초로 다른 지점: 인덱스 {i}")
#             print(f"원본: {total_long_hex_string[i:i+10]}...")
#             print(f"파일: {loaded_hex_string[i:i+10]}...")
#             break
# Out:
# Weight 약간보자
# Start (MSB side): ...
# End (LSB side): ...
# ✅ 파일 저장 완료: init_weight.txt
# 총 Hex 글자 수: 883,200자
# 파일 용량: 441,600B
# 파일 용량: 0.421MB

# %% [markdown]
# ## config 및 weight 값 fpga 삽입

# %%
import time
import numpy as np
from mms_ok import XEM7310
from mms_ok import XEM7360
from secrets import token_hex
import torch
import random
from bh_utils import *


bitstream_path = r"bitstream/top_bh_fpga.bit"
fpga = XEM7360(bitstream_path=bitstream_path)
# fpga.close() 
def bh_btpipein(data, block_size_candidate = [16384, 8192, 4096, 2048, 1024, 512, 256, 128, 64, 32, 16], verbose = True):
# def bh_btpipein(data, block_size_candidate = [16384, 16], verbose = False):
    total_start = time.time()

    left_string_len = len(data)
    read_string_len = 0

    if (verbose):
        print(f"\n\n")
        print(f"bh_btpipein VERBOSE")

    for bl_size in block_size_candidate:
        if (left_string_len >= bl_size*2):
            read_string_len_temp = (left_string_len // (bl_size*2)) * (bl_size*2)
            sent_bytes = read_string_len_temp // 2
            
            # --- 각 블록 전송 시간 및 속도 측정 ---
            step_start = time.time()
            # data_temp = data[read_string_len : read_string_len + read_string_len_temp]
            fpga.WriteToBlockPipeIn(0x80, data[read_string_len : read_string_len + read_string_len_temp], block_size=bl_size, reorder_str=True)

            step_end = time.time()
            duration = step_end - step_start
            
            # MiB/s 계산 (bytes / 1024^2 / sec)
            speed = (sent_bytes / (1024 * 1024)) / duration if duration > 0 else 0

            if (verbose):
                print(f"{bl_size:10d} byte | {duration*1000:10.4f} ms | {speed:12.2f} MiB/s | {sent_bytes:12d} bytes")
                print(f'data_temp 뒷 네글자: {(data[read_string_len : read_string_len + read_string_len_temp])[-4:]}')

            left_string_len -= read_string_len_temp
            read_string_len += read_string_len_temp

    total_end = time.time()
    assert left_string_len == 0 and read_string_len == len(data), f"left_string_len: {left_string_len}, read_string_len: {read_string_len}, len(data): {len(data)}"
    if (verbose):
        print("-" * 30)
        print(f"Total Time: {total_end - total_start:.4f} sec")
        print(f"Total Bytes: {read_string_len//2} bytes")
        print(f"bh_btpipein VERBOSE END\n\n")
# ######### Reset ######################################################################
# ######### Reset ######################################################################
# ######### Reset ######################################################################
# ######### Reset ######################################################################
reset_time = 0.5  # seconds
print(f'Resetting FPGA for {reset_time} seconds...')
fpga.reset(reset_address = 0x00, reset_time = reset_time, active_low = True)
print('System reset complete.')
time.sleep(0.5) # 이거 꼭 해라
fpga.CheckTriggered(0x60, 1, timeout=10.0) # config 다됐냐
# ######### Reset ######################################################################
# ######### Reset ######################################################################
# ######### Reset ######################################################################
# ######### Reset ######################################################################

print('')
print('')
print('')
print('')

# fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
# ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
# print(f'WireOut 0x20 value: {ep20wireout}')
# ep21wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x21))
# print(f'WireOut 0x21 value: {ep21wireout}')


















# ######### phase조절하자 mode ######################################################################
# ######### phase조절하자 mode ######################################################################
# ######### phase조절하자 mode ######################################################################
# ######### phase조절하자 mode ######################################################################
print('\n\n\n')
fpga.SetWireInValue(0x01, signed_encoding_32bit(1))
phase_change_num = 3
if phase_change_num > 0:
    for iii in range(abs(phase_change_num)):
        fpga.ActivateTriggerIn(0x40, 24) # Go phase minus
        fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐
    print(f'######### Phase {phase_change_num} Change Complete ######################################################################')
    print(f'######### Phase {phase_change_num} Change Complete ######################################################################')
    print(f'######### Phase {phase_change_num} Change Complete ######################################################################')
elif phase_change_num < 0:
    for iii in range(abs(phase_change_num)):
        fpga.ActivateTriggerIn(0x40, 21) # Go phase plus
        fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐
    print(f'######### Phase {phase_change_num} Change Complete ######################################################################')
    print(f'######### Phase {phase_change_num} Change Complete ######################################################################')
    print(f'######### Phase {phase_change_num} Change Complete ######################################################################')
else:
    print('######### No phase change ######################################################################')
    print('######### No phase change ######################################################################')
    print('######### No phase change ######################################################################')
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
print('\n\n\n')



# ######### phase2조절하자 mode ######################################################################
# ######### phase2조절하자 mode ######################################################################
# ######### phase2조절하자 mode ######################################################################
# ######### phase2조절하자 mode ######################################################################
print('\n\n\n')
fpga.SetWireInValue(0x01, signed_encoding_32bit(2))
phase2_change_num = 3
if phase2_change_num > 0:
    for iii in range(abs(phase2_change_num)):
        fpga.ActivateTriggerIn(0x40, 18) # Go phase2 minus
        fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐
    print(f'######### Phase2 {phase2_change_num} Change Complete ######################################################################')
    print(f'######### Phase2 {phase2_change_num} Change Complete ######################################################################')
    print(f'######### Phase2 {phase2_change_num} Change Complete ######################################################################')
elif phase2_change_num < 0:
    for iii in range(abs(phase2_change_num)):
        fpga.ActivateTriggerIn(0x40, 17) # Go phase2 plus
        fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐
    print(f'######### Phase2 {phase2_change_num} Change Complete ######################################################################')
    print(f'######### Phase2 {phase2_change_num} Change Complete ######################################################################')
    print(f'######### Phase2 {phase2_change_num} Change Complete ######################################################################')
else:
    print('######### No phase2 change ######################################################################')
    print('######### No phase2 change ######################################################################')
    print('######### No phase2 change ######################################################################')
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
print('\n\n\n')




















# ######### p_config mode ######################################################################
p_config_ongoing_sleep_time = 0.01  # seconds
p_config_verbose = False
# config mode on
print(f'######### P_STATE_01_WORKLOAD_CONFIG mode ######################################################################')
fpga.SetWireInValue(0x01, signed_encoding_32bit(1))
fpga.ActivateTriggerIn(0x40, 0)
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
# asic_mode: 0 training_only, 1 train_inf_sweep, 2 inference_only 
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['asic_mode']['value']))
fpga.ActivateTriggerIn(0x40, p_config['asic_mode']['trigger'])
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['asic_mode']['trigger']))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
if p_config_verbose:
    print(f'WireOut 0x20 value: {ep20wireout} <-- asic_mode')
time.sleep(p_config_ongoing_sleep_time)
# training_epochs
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['training_epochs']['value']))
fpga.ActivateTriggerIn(0x40, p_config['training_epochs']['trigger'])
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['training_epochs']['trigger']))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
if p_config_verbose:
    print(f'WireOut 0x20 value: {ep20wireout} <-- training_epochs')
time.sleep(p_config_ongoing_sleep_time)
# inference_epochs
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['inference_epochs']['value']))
fpga.ActivateTriggerIn(0x40, p_config['inference_epochs']['trigger'])
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['inference_epochs']['trigger']))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
if p_config_verbose:
    print(f'WireOut 0x20 value: {ep20wireout} <-- inference_epochs')
time.sleep(p_config_ongoing_sleep_time)
# dataset: 0 DVS_GESTURE, 1 N_MNIST, 2 NTIDIGITS
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['dataset']['value']))
fpga.ActivateTriggerIn(0x40, p_config['dataset']['trigger'])
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['dataset']['trigger']))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
if p_config_verbose:
    print(f'WireOut 0x20 value: {ep20wireout} <-- dataset')
time.sleep(p_config_ongoing_sleep_time)
# timesteps
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['timesteps']['value']))
fpga.ActivateTriggerIn(0x40, p_config['timesteps']['trigger'])
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['timesteps']['trigger']))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
if p_config_verbose:
    print(f'WireOut 0x20 value: {ep20wireout} <-- timesteps')
time.sleep(p_config_ongoing_sleep_time)
# input_size_layer1_define
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['input_size_layer1']['value']))
fpga.ActivateTriggerIn(0x40, p_config['input_size_layer1']['trigger'])
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['input_size_layer1']['trigger']))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
if p_config_verbose:
    print(f'WireOut 0x20 value: {ep20wireout} <-- input_size_layer1')
time.sleep(p_config_ongoing_sleep_time)
# long_time_input_streaming_mode
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['long_time_input_streaming_mode']['value']))
fpga.ActivateTriggerIn(0x40, p_config['long_time_input_streaming_mode']['trigger'])
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['long_time_input_streaming_mode']['trigger']))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
if p_config_verbose:
    print(f'WireOut 0x20 value: {ep20wireout} <-- long_time_input_streaming_mode')
time.sleep(p_config_ongoing_sleep_time)
# binary_classifier_mode
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['binary_classifier_mode']['value']))
fpga.ActivateTriggerIn(0x40, p_config['binary_classifier_mode']['trigger'])
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['binary_classifier_mode']['trigger']))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
if p_config_verbose:
    print(f'WireOut 0x20 value: {ep20wireout} <-- binary_classifier_mode')
time.sleep(p_config_ongoing_sleep_time)
# loser_encourage_mode
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['loser_encourage_mode']['value']))
fpga.ActivateTriggerIn(0x40, p_config['loser_encourage_mode']['trigger'])
fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['loser_encourage_mode']['trigger']))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
if p_config_verbose:
    print(f'WireOut 0x20 value: {ep20wireout} <-- loser_encourage_mode')
time.sleep(p_config_ongoing_sleep_time)
# layer1_cut_list
for i in range(15):
    fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['layer1_cut_list']['value'][i]))
    fpga.ActivateTriggerIn(0x40, p_config['layer1_cut_list']['trigger'])
    fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['layer1_cut_list']['trigger']))
    time.sleep(p_config_ongoing_sleep_time)
    ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    if p_config_verbose:
        print(f'WireOut 0x20 value: {ep20wireout} <-- layer1_cut_list[{i}]')
# layer2_cut_list
for i in range(15):
    fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['layer2_cut_list']['value'][i]))
    fpga.ActivateTriggerIn(0x40, p_config['layer2_cut_list']['trigger'])
    fpga.SetWireInValue(0x01, signed_encoding_32bit(p_config['layer2_cut_list']['trigger']))
    time.sleep(p_config_ongoing_sleep_time)
    ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    if p_config_verbose:
        print(f'WireOut 0x20 value: {ep20wireout} <-- layer2_cut_list[{i}]')
# ######### p_config mode######################################################################
        
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))

fpga.ActivateTriggerIn(0x40, 31)

fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐




    
print('')
print('')
print('')
print('')

# ######### p_config done mode ######################################################################
print(f'######### P_STATE_02_WORKLOAD_CONFIG_DONE mode ######################################################################')
fpga.SetWireInValue(0x01, signed_encoding_32bit(2))
fpga.ActivateTriggerIn(0x40, 0)
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
# ######### p_config done mode ######################################################################


    
print('')
print('')
print('')
print('')



# ######### P_STATE_03_DRAMFILL_WEIGHT_DATA mode ######################################################################
print(f'######### P_STATE_03_DRAMFILL_WEIGHT_DATA mode ######################################################################')
fpga.SetWireInValue(0x01, signed_encoding_32bit(3))
fpga.ActivateTriggerIn(0x40, 0)
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))


print(f'\nDRAM WRITE ADDRESS CONFIG!!!!!!!!!!!!')
print(f'dram_address_weight_start: {dram_address_weight_start:,}')
print(f'dram_address_weight_last: {dram_address_weight_last:,}')












# #DRAM WRITE ADDRESS CONFIG!!!!!!!!!!!!
fpga.SetWireInValue(0x01, signed_encoding_32bit(dram_address_weight_start)) # dram write address
fpga.ActivateTriggerIn(0x40, 30)
fpga.SetWireInValue(0x01, signed_encoding_32bit(dram_address_weight_last)) # dram write address last
fpga.ActivateTriggerIn(0x40, 30)
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐
# data = "01"*4 + "02"*4 + "03"*4 + "04"*4 + "05"*4 + "06"*4 + "07"*4 + "08"*4 + "09"*4 + "0A"*4 + "0B"*4 + "0C"*4 + "0D"*4 + "0E"*4 + "0F"*4 + "10"*4
# data = "01"*4 + "02"*4 + "03"*4 + "04"*4 + "05"*4 + "06"*4 + "07"*4 + "08"*4 + "09"*4 + "0A"*4 + "0B"*4 + "0C"*4 + "0D"*4 + "0E"*4 + "0F"*4 + "0F"*4
with open("init_weight.txt", "r") as f:
    loaded_hex_string = f.read()
data = loaded_hex_string
# data = loaded_hex_string[-64:]




# #DRAM WRITE ADDRESS CONFIG!!!!!!!!!!!!
# check_n_bits = 256 *      3  
# fpga.SetWireInValue(0x01, signed_encoding_32bit(0)) # dram write address
# fpga.ActivateTriggerIn(0x40, 30)
# fpga.SetWireInValue(0x01, signed_encoding_32bit(0 + (check_n_bits-256)//32 )) # dram write address last
# fpga.ActivateTriggerIn(0x40, 30)
# fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
# fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐
# with open("init_weight.txt", "r") as f:
#     loaded_hex_string = f.read()
# # data = "01"*4 + "02"*4 + "03"*4 + "04"*4 + "05"*4 + "06"*4 + "07"*4 + "08"*4 + "09"*4 + "0A"*4 + "0B"*4 + "0C"*4 + "0D"*4 + "0E"*4 + "0F"*4 + "FF"*4
# # data = "09"*4 + "0A"*4 + "0B"*4 + "0C"*4 + "0D"*4 + "0E"*4 + "0F"*4 + "FF"*4
# # data = "09"*4 + "0A"*4 + "0B"*4 + "0C"*4 + "0D"*4 + "0E"*4 + "0F"*4 + "0B"*4
# data = token_hex(check_n_bits//8) # byte
# print(f'테스트 data[-2:0] {data[-2:0]}', f'data length: {len(data)}')
# print(f'테스트 data[-2:0] {data[-2:0]}', f'data length: {len(data)}')
# print(f'테스트 data[-2:0] {data[-2:0]}', f'data length: {len(data)}')







# print(f'datain string length: {len(data)}') # 883200 (883200*2 byte)

# # block size (byte)  (len(data)*2) 가 아래숫자에 배수여야함.
# # USB 2.0 FullSpeed - Multiple of two [2..64]
# # USB 2.0 HighSpeed - Multiple of two [2..1024]
# # USB 3.0 FullSpeed - Power of two [16..64]
# # USB 3.0 HighSpeed - Power of two [16..1024]
# # USB 3.0 SuperSpeed - Power of two [16..16384]
# block_size_candidate = [16384, 8192, 4096, 2048, 1024, 512, 256, 128, 64, 32, 16]
# block_size_candidate = [16384, 16]
# block_size_candidate = [16384, 32]
# block_size_candidate = [16384, 64]
# block_size_candidate = [16]
# verbose = True
# bh_btpipein(data, block_size_candidate = [16384, 64], verbose = True) # block_size_candidate should be >= 64 and 2의 승수.



############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
bh_btpipein(data, verbose = True) # block_size_candidate should be >= 64 and 2의 승수.
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################



fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐
# ######### P_STATE_03_DRAMFILL_WEIGHT_DATA mode ######################################################################







print('')
print('')
print('')
print('')









print(f'######### P_STATE_04_DRAMFILL_WEIGHT_DATA_DONE mode ######################################################################')
# ######### P_STATE_04_DRAMFILL_WEIGHT_DATA_DONE mode ######################################################################

fpga.SetWireInValue(0x01, signed_encoding_32bit(12))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'wr_en cnt value = WireOut 0x20 value: {ep20wireout}')
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))

# fpga.SetWireInValue(0x01, signed_encoding_32bit(1))
# fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
# ######### P_STATE_04_DRAMFILL_WEIGHT_DATA_DONE mode ######################################################################







print('')
print('')
print('')
print('')
# Out:
# 2026-01-27 23:03:47.700 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:28 - FrontPanel SDK Version: 5.3.6
# 2026-01-27 23:03:47.704 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:39 - FrontPanel API ready
# 2026-01-27 23:03:47.955 | INFO     | mms_ok.fpga:_validate_bitstream_path:117 - Bitstream file: c:\Users\bhkim\measurement_setting\bitstream\top_bh_fpga.bit
# 2026-01-27 23:03:47.955 | INFO     | mms_ok.fpga:_validate_bitstream_path:120 - Bitstream date: 2026-01-27 16:55:42
# 2026-01-27 23:03:47.962 | INFO     | mms_ok.fpga:_connect:147 - Model        : XEM7360-K160T
# 2026-01-27 23:03:47.962 | INFO     | mms_ok.fpga:_connect:148 - Serial Number: 2420001BL5
# 2026-01-27 23:03:47.963 | INFO     | mms_ok.fpga:_connect:149 - Interface    : USB 3
# 2026-01-27 23:03:47.964 | INFO     | mms_ok.fpga:_connect:150 - USB Speed    : SUPER
# 2026-01-27 23:03:47.964 | INFO     | mms_ok.fpga:_connect:151 - Max Blocksize: 16384
# 2026-01-27 23:03:47.965 | INFO     | mms_ok.fpga:_connect:152 - Wire Width   : 32
# 2026-01-27 23:03:47.965 | INFO     | mms_ok.fpga:_connect:153 - Trigger Width: 32
# 2026-01-27 23:03:47.967 | INFO     | mms_ok.fpga:_connect:154 - Pipe Width   : 32
# 2026-01-27 23:03:48.464 | INFO     | mms_ok.fpga:_configure:172 - Input bitstream file: "top_bh_fpga.bit" is connected to the device!
# 2026-01-27 23:03:48.465 | INFO     | mms_ok.fpga:_configure:184 - FrontPanel is enabled!
# 2026-01-27 23:03:48.467 | INFO     | mms_ok.fpga:_check_device_settings:703 - Please check the I/O voltage settings.
# 2026-01-27 23:03:48.467 | INFO     | mms_ok.fpga:_check_device_settings:704 - Bank 12 Voltage: 180 mV
# 2026-01-27 23:03:48.468 | INFO     | mms_ok.fpga:_check_device_settings:705 - Bank 15 Voltage: 180 mV
# 2026-01-27 23:03:48.468 | INFO     | mms_ok.fpga:_check_device_settings:706 - Bank 16 Voltage: 180 mV
# 2026-01-27 23:03:48.469 | INFO     | mms_ok.fpga:_check_device_settings:707 - Bank 32 Voltage: 180 mV
# 2026-01-27 23:03:48.469 | INFO     | mms_ok.fpga:__init__:85 - AutoWireIn is enabled!
# 2026-01-27 23:03:48.470 | INFO     | mms_ok.fpga:__init__:86 - AutoWireOut is enabled!
# 2026-01-27 23:03:48.470 | INFO     | mms_ok.fpga:__init__:89 - AutoTriggerOut is enabled!
# 2026-01-27 23:03:48.471 | INFO     | mms_ok.fpga:__init__:92 - FPGA initialized!
#
# 2026-01-27 23:03:48.472 | INFO     | mms_ok.fpga:reset:264 - Reset Start (0.5s)
# Resetting FPGA for 0.5 seconds...
# 2026-01-27 23:03:48.978 | INFO     | mms_ok.fpga:reset:272 - Reset End (0.5s)
# System reset complete.
#
#
#
#
# ######### P_STATE_01_WORKLOAD_CONFIG mode ######################################################################
#
#
#
#
# ######### P_STATE_02_WORKLOAD_CONFIG_DONE mode ######################################################################
#
#
#
#
# ######### P_STATE_03_DRAMFILL_WEIGHT_DATA mode ######################################################################
#
# DRAM WRITE ADDRESS CONFIG!!!!!!!!!!!!
# dram_address_weight_start: 0
# dram_address_weight_last: 110,392
#
#
#
# bh_btpipein VERBOSE
#      16384 byte |    47.2870 ms |         8.59 MiB/s |       425984 bytes
# data_temp 뒷 네글자: 000e
#       8192 byte |     1.0095 ms |         7.74 MiB/s |         8192 bytes
# data_temp 뒷 네글자: 000d
#       4096 byte |     0.9959 ms |         3.92 MiB/s |         4096 bytes
# data_temp 뒷 네글자: 000a
#       2048 byte |     0.0000 ms |         0.00 MiB/s |         2048 bytes
# data_temp 뒷 네글자: 00ff
#       1024 byte |     0.0000 ms |         0.00 MiB/s |         1024 bytes
# data_temp 뒷 네글자: 000e
#        256 byte |     1.0002 ms |         0.24 MiB/s |          256 bytes
# data_temp 뒷 네글자: 00f7
# ------------------------------
# Total Time: 0.0503 sec
# Total Bytes: 441600 bytes
# bh_btpipein VERBOSE END
#
#
#
#
#
#
# ######### P_STATE_04_DRAMFILL_WEIGHT_DATA_DONE mode ######################################################################
# wr_en cnt value = WireOut 0x20 value: 110400

# %%
print('dram_address_weight_start')
fpga.SetWireInValue(0x01, signed_encoding_32bit(10))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

print('dram_address_weight_last')
fpga.SetWireInValue(0x01, signed_encoding_32bit(11))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')


print('write count before trigging', '(하위 17비트)')
fpga.SetWireInValue(0x01, signed_encoding_32bit(13))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
fpga.ActivateTriggerIn(0x40, 29)
fpga.CheckTriggered(0x60, 1, timeout=1.0)
print('write count after trigging', '(하위 17비트)')
fpga.SetWireInValue(0x01, signed_encoding_32bit(13))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

print('fifo_p2d_data_wr_cnt')
fpga.SetWireInValue(0x01, signed_encoding_32bit(12))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

print('쓴 데이터의 마지막 16bit')
fpga.SetWireInValue(0x01, signed_encoding_32bit(14))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
# 수정 전: unsigned hex: 0xf659
# 수정 후: unsigned hex: f659 (딱 4자리)
string_from_fpga = f'{fpga.GetWireOutValue(0x20):04x}'
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {string_from_fpga}')
print('넣은거  ', data[-4:])
print('넣은 거랑 똑같음?',str(data[-4:]) == str(string_from_fpga))
# print(f'len(data): {len(data)}')
if str(data[-4:]) != str(string_from_fpga):
    if  str(string_from_fpga) in str(data):
        #몇번째에
        idx = data.index(str(string_from_fpga))
        print(f'안에있음, {idx}번째에 있음')
        print(f'len(data) - idx: {len(data) - idx}')
    else:
        print('안에없음')
    

fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
# Out:
# dram_address_weight_start
# value = WireOut 0x20 value: 0 unsigned hex: 0x0
# dram_address_weight_last
# value = WireOut 0x20 value: 110392 unsigned hex: 0x1af38
# write count before trigging (하위 17비트)
# value = WireOut 0x20 value: 0 unsigned hex: 0x0
# write count after trigging (하위 17비트)
# value = WireOut 0x20 value: 110400 unsigned hex: 0x1af40
# fifo_p2d_data_wr_cnt
# value = WireOut 0x20 value: 110400 unsigned hex: 0x1af40
# 쓴 데이터의 마지막 16bit
# value = WireOut 0x20 value: 247 unsigned hex: 00f7
# 넣은거   00f7
# 넣은 거랑 똑같음? True
# 0

# %% [markdown]
# ## inference data 삽입

# %%
print(f'######### P_STATE_05_DRAMFILL_INFERENCE_DATA mode ######################################################################')
# ######### P_STATE_05_DRAMFILL_INFERENCE_DATA mode ######################################################################
fpga.SetWireInValue(0x01, signed_encoding_32bit(5))
fpga.ActivateTriggerIn(0x40, 0)
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))




if dataset == 'DVS_GESTURE':
    bit_per_sample = 9984
    inf_samples = 240
    tr_samples = 979
    tr_epochs_in_dram = 200

    # 9984 bit * 240 samples
    dram_address_inference_start = 110_400
    dram_address_inference_last =  dram_address_inference_start + ((bit_per_sample * inf_samples) // 32) - 8 # 185_272

    # 9984 bit * 979 samples * 200 epochs
    dram_address_training_start = 1_070_400
    dram_address_training_last = dram_address_training_start + (((bit_per_sample * tr_samples) // 32)*tr_epochs_in_dram) - 8  # 62_159_992

    inference_data_path = f"zz_measure_dataset/gesture/topN_{topN_at_gesture}/seed_{my_seed}/test"
    training_data_path = f"zz_measure_dataset/gesture/topN_{topN_at_gesture}/seed_{my_seed}/train"
    file_name_prefix = "gesture"

elif dataset == 'N_MNIST':
    # training 때 25epochs만넣을거임 nmnist는!!!!!!!!!!!!!!!!!!!!!!!!!!!

    bit_per_sample = 3072
    inf_samples = 10000
    tr_samples = 60000
    tr_epochs_in_dram = 50

    # 3072 bit * 10000 samples
    dram_address_inference_start = 110_400
    dram_address_inference_last = dram_address_inference_start + ((bit_per_sample * inf_samples) // 32) - 8 # 1_070_392

    # 3072 bit * 60000 samples * 25 epochs
    dram_address_training_start = 1_070_400
    dram_address_training_last = dram_address_training_start + (((bit_per_sample * tr_samples) // 32)*tr_epochs_in_dram) - 8 # 145_070_392

    inference_data_path = f"zz_measure_dataset/nmnist/test"
    training_data_path = f"zz_measure_dataset/nmnist/train"
    file_name_prefix = "nmnist"

elif dataset == 'NTIDIGITS':

    bit_per_sample = 4352
    inf_samples = 452
    if target_word_at_ntidigits in [0]:
        tr_samples = 4032
    elif target_word_at_ntidigits in [1,2,3,4,5,6,7,8,9]:
        tr_samples = 4030
    else:
        assert False, "NTIDIGITS target word 설정 필요"
    tr_epochs_in_dram = 200

    # 4352 bit * n samples
    dram_address_inference_start = 110_400
    dram_address_inference_last = dram_address_inference_start + ((bit_per_sample * inf_samples) // 32) - 8 # 171,864

    # 4352 bit * n samples * 200 epochs
    dram_address_training_start = 1_070_400
    dram_address_training_last = dram_address_training_start + (((bit_per_sample * tr_samples) // 32)*tr_epochs_in_dram) - 8  #110,740,792 #at word0 110,686,392

    inference_data_path = f"zz_measure_dataset/ntidigits/word{target_word_at_ntidigits}/test"
    training_data_path = f"zz_measure_dataset/ntidigits/word{target_word_at_ntidigits}/train"
    file_name_prefix = f"ntidigits_word{target_word_at_ntidigits}"

else:
    assert False, "데이터셋 설정 필요"

saved_path = f"{inference_data_path}/01_total_inference_data.txt"
if os.path.exists(saved_path) == True:
    print('이미 total inference dataset 파일이 존재하여 그것을 불러옵니다.', f'path : {saved_path}')
    with open(saved_path, "r") as f:
        total_inference_dataset_hex_string = f.read()
else:
    print('total inference dataset 파일이 존재하지 않아 새로 만듭니다.', f'path : {saved_path}')
    # inference making
    inference_dataset = []
    for sample_idx in range(inf_samples):
        sample_path = f"{inference_data_path}/{file_name_prefix}_{sample_idx}.txt"
        
        # 파일이 존재하는지 확인
        if not os.path.exists(sample_path):
            print(f"파일을 찾을 수 없습니다: {sample_path}. 루프를 종료합니다.")
            break
            
        with open(sample_path, "r") as f:
            sample_hex_string = f.read()
            inference_dataset.append(sample_hex_string)
    total_inference_dataset_hex_string = "".join(inference_dataset)
    with open(saved_path, "w") as f:
        f.write(total_inference_dataset_hex_string)

with open("total_inference_dataset_hex_string.txt", "w") as f:
    f.write(total_inference_dataset_hex_string)

with open("total_inference_dataset_hex_string.txt", "r") as f:
    total_inference_dataset_hex_string = f.read()

print(f'len(total_inference_dataset_hex_string): {len(total_inference_dataset_hex_string)} x 4bit')
print(f'dram_address_inference_last - dram_address_inference_start + 8: {dram_address_inference_last - dram_address_inference_start + 8} x 32bit')






print(f'\nDRAM WRITE ADDRESS CONFIG!!!!!!!!!!!!')
print(f'dram_address_inference_start: {dram_address_inference_start:,}')
print(f'dram_address_inference_last: {dram_address_inference_last:,}')
fpga.SetWireInValue(0x01, signed_encoding_32bit(dram_address_inference_start)) # dram write address
fpga.ActivateTriggerIn(0x40, 30)
fpga.SetWireInValue(0x01, signed_encoding_32bit(dram_address_inference_last)) # dram write address last
fpga.ActivateTriggerIn(0x40, 30)
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐




print('\nwrite count before trigging', '(하위 17비트)' , 'address 재설정하면 0으로 리셋 돼 있음. trigging해보셈.')
fpga.SetWireInValue(0x01, signed_encoding_32bit(13))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
fpga.ActivateTriggerIn(0x40, 29)
fpga.CheckTriggered(0x60, 1, timeout=1.0)
print('write count after trigging', '(하위 17비트)')
fpga.SetWireInValue(0x01, signed_encoding_32bit(13))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')







print('\n\ndram address 잘 드갔나?')
print('dram_address_weight_start')
fpga.SetWireInValue(0x01, signed_encoding_32bit(10))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

print('dram_address_weight_last')
fpga.SetWireInValue(0x01, signed_encoding_32bit(11))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
print('\n')
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))














print('dataset의 앞 64글자와 뒤 64글자')
print(f"Start (MSB side): {total_inference_dataset_hex_string[:64]}...")
print(f"End (LSB side): ...{total_inference_dataset_hex_string[-64:]}")



data = total_inference_dataset_hex_string





print(f'data length: {len(data)}')

############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
bh_btpipein(data, verbose = True) # block_size_candidate should be >= 64 and 2의 승수.
# bh_btpipein(data, verbose = False) # block_size_candidate should be >= 64 and 2의 승수.
# fpga.WriteToBlockPipeIn(0x80, data[0:16384*2], reorder_str=True)
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################




fpga.CheckTriggered(0x60, 1, timeout=2.0) # config 다됐냐
# ######### P_STATE_05_DRAMFILL_INFERENCE_DATA mode ######################################################################





print('')
print('')
print('')
print('')
# Out:
# ######### P_STATE_05_DRAMFILL_INFERENCE_DATA mode ######################################################################
# 이미 total inference dataset 파일이 존재하여 그것을 불러옵니다. path : zz_measure_dataset/nmnist/test/01_total_inference_data.txt
# len(total_inference_dataset_hex_string): 7680000 x 4bit
# dram_address_inference_last - dram_address_inference_start + 8: 960000 x 32bit
#
# DRAM WRITE ADDRESS CONFIG!!!!!!!!!!!!
# dram_address_inference_start: 110,400
# dram_address_inference_last: 1,070,392
#
# write count before trigging (하위 17비트) address 재설정하면 0으로 리셋 돼 있음. trigging해보셈.
# value = WireOut 0x20 value: 110400 unsigned hex: 0x1af40
# write count after trigging (하위 17비트)
# value = WireOut 0x20 value: 0 unsigned hex: 0x0
#
#
# dram address 잘 드갔나?
# dram_address_weight_start
# value = WireOut 0x20 value: 110400 unsigned hex: 0x1af40
# dram_address_weight_last
# value = WireOut 0x20 value: 1070392 unsigned hex: 0x105538
#
#
# dataset의 앞 64글자와 뒤 64글자
# Start (MSB side): 00000000000000000000000000000000000000001c1000000000000000000c00...
# End (LSB side): ...000000000000003f4000200e1000000000001000000000001800100000000000
# data length: 7680000
#
#
#
# bh_btpipein VERBOSE
#      16384 byte |   443.0437 ms |         8.25 MiB/s |      3833856 bytes
# data_temp 뒷 네글자: 0000
#       4096 byte |     0.0000 ms |         0.00 MiB/s |         4096 bytes
# data_temp 뒷 네글자: 0180
#       2048 byte |     0.9983 ms |         1.96 MiB/s |         2048 bytes
# data_temp 뒷 네글자: 0000
# ------------------------------
# Total Time: 0.4460 sec
# Total Bytes: 3840000 bytes
# bh_btpipein VERBOSE END

# %%
print('dram_address_weight_start')
fpga.SetWireInValue(0x01, signed_encoding_32bit(10))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

print('dram_address_weight_last')
fpga.SetWireInValue(0x01, signed_encoding_32bit(11))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')


print('write count before trigging', '(하위 17비트)')
fpga.SetWireInValue(0x01, signed_encoding_32bit(13))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
fpga.ActivateTriggerIn(0x40, 29)
fpga.CheckTriggered(0x60, 1, timeout=1.0)
print('write count after trigging', '(하위 17비트)')
fpga.SetWireInValue(0x01, signed_encoding_32bit(13))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

print('fifo_p2d_data_wr_cnt')
fpga.SetWireInValue(0x01, signed_encoding_32bit(12))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

print('쓴 데이터의 마지막 16bit')
fpga.SetWireInValue(0x01, signed_encoding_32bit(14))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
# 수정 전: unsigned hex: 0xf659
# 수정 후: unsigned hex: f659 (딱 4자리)
string_from_fpga = f'{fpga.GetWireOutValue(0x20):04x}'
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {string_from_fpga}')
# print('넣은거  ', data[-4:])
# print(data)
print('넣은 거랑 똑같음?',str(data[-4:]) == str(string_from_fpga))
# print(f'len(data): {len(data)}')
if str(data[-4:]) != str(string_from_fpga):
    if  str(string_from_fpga) in str(data):
        #몇번째에
        idx = data.index(str(string_from_fpga))
        print(f'안에있음, {idx}번째에 있음')
        print(f'len(data) - idx: {len(data) - idx}')
    else:
        print('안에없음')
    

fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
# Out:
# dram_address_weight_start
# value = WireOut 0x20 value: 110400 unsigned hex: 0x1af40
# dram_address_weight_last
# value = WireOut 0x20 value: 1070392 unsigned hex: 0x105538
# write count before trigging (하위 17비트)
# value = WireOut 0x20 value: 0 unsigned hex: 0x0
# write count after trigging (하위 17비트)
# value = WireOut 0x20 value: 42496 unsigned hex: 0xa600
# fifo_p2d_data_wr_cnt
# value = WireOut 0x20 value: 960000 unsigned hex: 0xea600
# 쓴 데이터의 마지막 16bit
# value = WireOut 0x20 value: 0 unsigned hex: 0000
# 넣은 거랑 똑같음? True
# 0

# %% [markdown]
# ## training data 삽입

# %%
print(f'######### P_STATE_06_DRAMFILL_TRAINING_DATA mode ######################################################################')
# ######### P_STATE_06_DRAMFILL_TRAINING_DATA mode ######################################################################
fpga.SetWireInValue(0x01, signed_encoding_32bit(6))
fpga.ActivateTriggerIn(0x40, 0)
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))



if dataset == 'DVS_GESTURE':
    saved_path = f"{training_data_path}/01_total_training_data_seed_{my_seed}.txt"
    if os.path.exists(saved_path) == True:
        print('이미 total training dataset 파일이 존재하여 그것을 불러옵니다.', f'path : {saved_path}')
        with open(saved_path, "r") as f:
            total_training_dataset_hex_string = f.read()
    else:
        print('total training dataset 파일이 존재하지 않아 새로 만듭니다.', f'path : {saved_path}')
        # 먼저 존재하는 파일들의 경로 리스트를 만듭니다.
        all_training_sample_paths = []
        for epoch in range(tr_epochs_in_dram):
            for sample_idx in range(tr_samples):
                sample_path = f"{training_data_path}/epoch_{epoch}/{file_name_prefix}_{sample_idx}.txt"
                if os.path.exists(sample_path):
                    all_training_sample_paths.append(sample_path)
                else:
                    assert False, f"파일을 찾을 수 없어: {sample_path}"

        # training making
        training_dataset = []
        for sample_path in all_training_sample_paths:
            with open(sample_path, "r") as f:
                sample_hex_string = f.read()
                training_dataset.append(sample_hex_string)
        total_training_dataset_hex_string = "".join(training_dataset)
        with open(saved_path, "w") as f:
            f.write(total_training_dataset_hex_string)

elif dataset == 'N_MNIST':
    print(f'NMNIST는 training data {tr_epochs_in_dram}epochs만')
    saved_path = f"{training_data_path}/01_total_training_data_seed_{my_seed}_epochs_{tr_epochs_in_dram}.txt"
    if os.path.exists(saved_path) == True:
        print('이미 total training dataset 파일이 존재하여 그것을 불러옵니다.', f'path : {saved_path}')
        with open(saved_path, "r") as f:
            total_training_dataset_hex_string = f.read()
    else:
        print('total training dataset 파일이 존재하지 않아 새로 만듭니다.', f'path : {saved_path}')
        # 먼저 존재하는 파일들의 경로 리스트를 만듭니다.
        all_training_sample_paths = []
        for sample_idx in range(tr_samples):
            sample_path = f"{training_data_path}/{file_name_prefix}_{sample_idx}.txt"
            if os.path.exists(sample_path):
                all_training_sample_paths.append(sample_path)
            else:
                assert False, f"파일을 찾을 수 없어: {sample_path}"

        # training making
        training_dataset = []
        for epoch in range(tr_epochs_in_dram):
            random.shuffle(all_training_sample_paths)
            for sample_path in all_training_sample_paths:
                with open(sample_path, "r") as f:
                    sample_hex_string = f.read()
                    training_dataset.append(sample_hex_string)
        total_training_dataset_hex_string = "".join(training_dataset)
        with open(saved_path, "w") as f:
            f.write(total_training_dataset_hex_string)

elif dataset == 'NTIDIGITS':
    saved_path = f"{training_data_path}/01_total_training_data_seed_{my_seed}.txt"
    if os.path.exists(saved_path) == True:
        print('이미 total training dataset 파일이 존재하여 그것을 불러옵니다.', f'path : {saved_path}')
        with open(saved_path, "r") as f:
            total_training_dataset_hex_string = f.read()
    else:
        print('total training dataset 파일이 존재하지 않아 새로 만듭니다.', f'path : {saved_path}')
        # 먼저 존재하는 파일들의 경로 리스트를 만듭니다.
        all_training_sample_paths = []
        for sample_idx in range(tr_samples):
            sample_path = f"{training_data_path}/{file_name_prefix}_{sample_idx}.txt"
            if os.path.exists(sample_path):
                all_training_sample_paths.append(sample_path)
            else:
                assert False, f"파일을 찾을 수 없어: {sample_path}"

        # training making
        training_dataset = []
        for epoch in range(tr_epochs_in_dram):
            random.shuffle(all_training_sample_paths)
            for sample_path in all_training_sample_paths:
                with open(sample_path, "r") as f:
                    sample_hex_string = f.read()
                    training_dataset.append(sample_hex_string)
        total_training_dataset_hex_string = "".join(training_dataset)
        with open(saved_path, "w") as f:
            f.write(total_training_dataset_hex_string)













# # for test
# # for test
# # for test
# # for test
# total_training_dataset_hex_string = token_hex(512//8) # byte
# dram_address_training_start = dram_address_training_start
# dram_address_training_last = dram_address_training_start + (512//32) - 8
# # for test
# # for test
# # for test















with open("total_training_dataset_hex_string.txt", "w") as f:
    f.write(total_training_dataset_hex_string)

with open("total_training_dataset_hex_string.txt", "r") as f:
    total_training_dataset_hex_string = f.read()

print(f'len(total_training_dataset_hex_string): {len(total_training_dataset_hex_string)} x 4bit')
print(f'dram_address_training_last - dram_address_training_start + 8: {dram_address_training_last - dram_address_training_start + 8} x 32bit')






print(f'\nDRAM WRITE ADDRESS CONFIG!!!!!!!!!!!!')
print(f'dram_address_training_start: {dram_address_training_start:,}')
print(f'dram_address_training_last: {dram_address_training_last:,}')
fpga.SetWireInValue(0x01, signed_encoding_32bit(dram_address_training_start)) # dram write address
fpga.ActivateTriggerIn(0x40, 30)
fpga.SetWireInValue(0x01, signed_encoding_32bit(dram_address_training_last)) # dram write address last
fpga.ActivateTriggerIn(0x40, 30)
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐


print('\nwrite count before trigging', '(하위 17비트)')
fpga.SetWireInValue(0x01, signed_encoding_32bit(13))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
fpga.ActivateTriggerIn(0x40, 29)
fpga.CheckTriggered(0x60, 1, timeout=1.0)
print('write count after trigging', '(하위 17비트)')
fpga.SetWireInValue(0x01, signed_encoding_32bit(13))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')




print('\n\ndram address 잘 드갔나?')
print('dram_address_weight_start')
fpga.SetWireInValue(0x01, signed_encoding_32bit(10))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

print('dram_address_weight_last')
fpga.SetWireInValue(0x01, signed_encoding_32bit(11))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
print('\n')


fpga.SetWireInValue(0x01, signed_encoding_32bit(0))








print('dataset의 앞 64글자와 뒤 64글자')
print(f"Start (MSB side): {total_training_dataset_hex_string[:64]}...")
print(f"End (LSB side): ...{total_training_dataset_hex_string[-64:]}")

data = total_training_dataset_hex_string







############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
# bh_btpipein(data, verbose = True) # block_size_candidate should be >= 64 and 2의 승수.
# bh_btpipein(data, verbose = False) # block_size_candidate should be >= 64 and 2의 승수.

if len(data) % 16*8 == 0:
    for slice_idx in range(8):
        bh_btpipein(data[(len(data)//8)*slice_idx:(len(data)//8)*(slice_idx+1)], verbose = True) # block_size_candidate should be >= 64 and 2의 승수.
else:
    assert False, f"데이터 길이가 16*8의 배수가 아님, len(data): {len(data)}"
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################
############## PIPE IN !!!!!!!!!!!!!!!!!! #####################




fpga.CheckTriggered(0x60, 1, timeout=60.0) # config 다됐냐
# ######### P_STATE_06_DRAMFILL_TRAINING_DATA mode ######################################################################





print('\n\n DRAM FILL FINISH')


print('')
print('')
print('')
print('')
# Out:
# ######### P_STATE_06_DRAMFILL_TRAINING_DATA mode ######################################################################
# NMNIST는 training data 50epochs만
# total training dataset 파일이 존재하지 않아 새로 만듭니다. path : zz_measure_dataset/nmnist/train/01_total_training_data_seed_0_epochs_50.txt
# len(total_training_dataset_hex_string): 2304000000 x 4bit
# dram_address_training_last - dram_address_training_start + 8: 288000000 x 32bit
#
# DRAM WRITE ADDRESS CONFIG!!!!!!!!!!!!
# dram_address_training_start: 1,070,400
# dram_address_training_last: 289,070,392
#
# write count before trigging (하위 17비트)
# value = WireOut 0x20 value: 42496 unsigned hex: 0xa600
# write count after trigging (하위 17비트)
# value = WireOut 0x20 value: 0 unsigned hex: 0x0
#
#
# dram address 잘 드갔나?
# dram_address_weight_start
# value = WireOut 0x20 value: 1070400 unsigned hex: 0x105540
# dram_address_weight_last
# value = WireOut 0x20 value: 289070392 unsigned hex: 0x113add38
#
#
# dataset의 앞 64글자와 뒤 64글자
# Start (MSB side): 0000000000000000000000000000000000000000240080000000000004000000...
# End (LSB side): ...00000000000000000003e0000000000070014000000000000000000000000000
#
#
#
# bh_btpipein VERBOSE
#      16384 byte | 22177.7318 ms |         6.19 MiB/s |    143998976 bytes
# data_temp 뒷 네글자: 0000
#       1024 byte |     1.2739 ms |         0.77 MiB/s |         1024 bytes
# data_temp 뒷 네글자: 0000
# ------------------------------
# Total Time: 22.2559 sec
# Total Bytes: 144000000 bytes
# bh_btpipein VERBOSE END
#
#
#
#
#
# bh_btpipein VERBOSE
#      16384 byte | 21407.2039 ms |         6.42 MiB/s |    143998976 bytes
# data_temp 뒷 네글자: 0000
#       1024 byte |     1.2803 ms |         0.76 MiB/s |         1024 bytes
# data_temp 뒷 네글자: 0000
# ------------------------------
# Total Time: 21.5057 sec
# Total Bytes: 144000000 bytes
# bh_btpipein VERBOSE END
#
#
#
#
#
# bh_btpipein VERBOSE
#      16384 byte | 21579.0746 ms |         6.36 MiB/s |    143998976 bytes
# data_temp 뒷 네글자: 0002
#       1024 byte |     1.0035 ms |         0.97 MiB/s |         1024 bytes
# data_temp 뒷 네글자: 0000
# ------------------------------
# Total Time: 21.6690 sec
# Total Bytes: 144000000 bytes
# bh_btpipein VERBOSE END
#
#
#
#
#
# bh_btpipein VERBOSE
#      16384 byte | 21374.7113 ms |         6.42 MiB/s |    143998976 bytes
# data_temp 뒷 네글자: 0000
#       1024 byte |     1.0026 ms |         0.97 MiB/s |         1024 bytes
# data_temp 뒷 네글자: 0000
# ------------------------------
# Total Time: 21.4816 sec
# Total Bytes: 144000000 bytes
# bh_btpipein VERBOSE END
#
#
#
#
#
# bh_btpipein VERBOSE
#      16384 byte | 20611.6862 ms |         6.66 MiB/s |    143998976 bytes
# data_temp 뒷 네글자: 0000
#       1024 byte |     0.0000 ms |         0.00 MiB/s |         1024 bytes
# data_temp 뒷 네글자: 0000
# ------------------------------
# Total Time: 20.6835 sec
# Total Bytes: 144000000 bytes
# bh_btpipein VERBOSE END
#
#
#
#
#
# bh_btpipein VERBOSE
#      16384 byte | 20600.5788 ms |         6.67 MiB/s |    143998976 bytes
# data_temp 뒷 네글자: 0000
#       1024 byte |     1.0037 ms |         0.97 MiB/s |         1024 bytes
# data_temp 뒷 네글자: 0000
# ------------------------------
# Total Time: 20.6726 sec
# Total Bytes: 144000000 bytes
# bh_btpipein VERBOSE END
#
#
#
#
#
# bh_btpipein VERBOSE
#      16384 byte | 21730.3035 ms |         6.32 MiB/s |    143998976 bytes
# data_temp 뒷 네글자: 0000
#       1024 byte |     1.2243 ms |         0.80 MiB/s |         1024 bytes
# data_temp 뒷 네글자: 0000
# ------------------------------
# Total Time: 21.8120 sec
# Total Bytes: 144000000 bytes
# bh_btpipein VERBOSE END
#
#
#
#
#
# bh_btpipein VERBOSE
#      16384 byte | 21248.5647 ms |         6.46 MiB/s |    143998976 bytes
# data_temp 뒷 네글자: 0800
#       1024 byte |     1.4918 ms |         0.65 MiB/s |         1024 bytes
# data_temp 뒷 네글자: 0000
# ------------------------------
# Total Time: 21.3266 sec
# Total Bytes: 144000000 bytes
# bh_btpipein VERBOSE END
#
#
#
#
#  DRAM FILL FINISH

# %%
print('dram_address_weight_start')
fpga.SetWireInValue(0x01, signed_encoding_32bit(10))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

print('dram_address_weight_last')
fpga.SetWireInValue(0x01, signed_encoding_32bit(11))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')


print('write count before trigging', '(하위 17비트)')
fpga.SetWireInValue(0x01, signed_encoding_32bit(13))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
fpga.ActivateTriggerIn(0x40, 29)
fpga.CheckTriggered(0x60, 1, timeout=1.0)
print('write count after trigging', '(하위 17비트)')
fpga.SetWireInValue(0x01, signed_encoding_32bit(13))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

print('fifo_p2d_data_wr_cnt')
fpga.SetWireInValue(0x01, signed_encoding_32bit(12))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

print('쓴 데이터의 마지막 16bit')
fpga.SetWireInValue(0x01, signed_encoding_32bit(14))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
# 수정 전: unsigned hex: 0xf659
# 수정 후: unsigned hex: f659 (딱 4자리)
string_from_fpga = f'{fpga.GetWireOutValue(0x20):04x}'
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {string_from_fpga}')
# print('넣은거  ', data[-4:])
# print(data)
print('넣은 거랑 똑같음?',str(data[-4:]) == str(string_from_fpga))
# print(f'len(data): {len(data)}')
if str(data[-4:]) != str(string_from_fpga):
    if  str(string_from_fpga) in str(data):
        #몇번째에
        idx = data.index(str(string_from_fpga))
        print(f'안에있음, {idx}번째에 있음')
        print(f'len(data) - idx: {len(data) - idx}')
    else:
        print('안에없음')
    

fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
# Out:
# dram_address_weight_start
# value = WireOut 0x20 value: 1070400 unsigned hex: 0x105540
# dram_address_weight_last
# value = WireOut 0x20 value: 289070392 unsigned hex: 0x113add38
# write count before trigging (하위 17비트)
# value = WireOut 0x20 value: 0 unsigned hex: 0x0
# write count after trigging (하위 17비트)
# value = WireOut 0x20 value: 34816 unsigned hex: 0x8800
# fifo_p2d_data_wr_cnt
# value = WireOut 0x20 value: 288000000 unsigned hex: 0x112a8800
# 쓴 데이터의 마지막 16bit
# value = WireOut 0x20 value: 0 unsigned hex: 0000
# 넣은 거랑 똑같음? True
# 0

# %% [markdown]
# ## ASIC에 CONFIG 밀어 넣기

# %%
print(f'######### P_STATE_07_ASIC_CONFIG mode ######################################################################')
# ######### P_STATE_07_ASIC_CONFIG mode ######################################################################
fpga.SetWireInValue(0x01, signed_encoding_32bit(7))
fpga.ActivateTriggerIn(0x40, 0)
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))




print(f'\nDRAM WEIGHT READ ADDRESS CONFIG!!!!!!!!!!!!')
print(f'dram_address_weight_start: {dram_address_weight_start:,}')
print(f'dram_address_weight_last: {dram_address_weight_last:,}')
fpga.SetWireInValue(0x01, signed_encoding_32bit(dram_address_weight_start)) # dram write address
fpga.ActivateTriggerIn(0x40, 30)
fpga.SetWireInValue(0x01, signed_encoding_32bit(dram_address_weight_last)) # dram write address last
fpga.ActivateTriggerIn(0x40, 30)
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐



print('\n\ndram address 잘 드갔나?')
print('dram_address_weight_start')
fpga.SetWireInValue(0x01, signed_encoding_32bit(10))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

print('dram_address_weight_last')
fpga.SetWireInValue(0x01, signed_encoding_32bit(11))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
print('\n')



streaming_wait_cycle = 4
assert 0 <= streaming_wait_cycle
print(f'STREAMING WAIT CYCLE 설정: 7번 넣고 {streaming_wait_cycle}번 사이클 기다림.')
fpga.SetWireInValue(0x01, signed_encoding_32bit(streaming_wait_cycle))
fpga.ActivateTriggerIn(0x40, 27)
fpga.CheckTriggered(0x60, 1, timeout=1.0)
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))




# ASIC start ready 확인
fpga.ActivateTriggerIn(0x40, 28)
fpga.CheckTriggered(0x60, 1, timeout=1.0)
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'\nASIC start ready 확인 = WireOut 0x20 value: {ep20wireout} (1이면 준비된 것) unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
assert ep20wireout == 1, "ASIC start 준비가 안된 상태임"






# config 시작!!!
print(f'\nASIC CONFIG 시작!')
fpga.ActivateTriggerIn(0x40, 0)
fpga.CheckTriggered(0x60, 1, timeout=5.0) # config 다됐냐
print(f'\nASIC CONFIG 종료!')




fpga.SetWireInValue(0x01, signed_encoding_32bit(1))
ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
print(f'a_domain에서 66bit stream 몇번? {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
fpga.SetWireInValue(0x01, signed_encoding_32bit(0))

# ######### P_STATE_07_ASIC_CONFIG mode ######################################################################








print('')
print('')
print('')
print('')
# Out:
# ######### P_STATE_07_ASIC_CONFIG mode ######################################################################
#
# DRAM WEIGHT READ ADDRESS CONFIG!!!!!!!!!!!!
# dram_address_weight_start: 0
# dram_address_weight_last: 110,392
#
#
# dram address 잘 드갔나?
# dram_address_weight_start
# value = WireOut 0x20 value: 0 unsigned hex: 0x0
# dram_address_weight_last
# value = WireOut 0x20 value: 110392 unsigned hex: 0x1af38
#
#
# STREAMING WAIT CYCLE 설정: 7번 넣고 4번 사이클 기다림.
#
# ASIC start ready 확인 = WireOut 0x20 value: 1 (1이면 준비된 것) unsigned hex: 0x1
#
# ASIC CONFIG 시작!
#
# ASIC CONFIG 종료!
# a_domain에서 66bit stream 몇번? 41424 unsigned hex: 0xa1d0

# %% [markdown]
# ## TRANING 1epoch & INFERENCE 1epoch * 200 SWEEPMODE!!!

# %%
DRAM_ADDRESS_INTERVAL_ONE_SAMPLE = bit_per_sample//32
EPOCH = 200
dram_address_training_start_origin = dram_address_training_start
dram_address_training_start_last_origin = dram_address_training_last
dram_address_training_start_next = dram_address_training_start
accuracy_list = []
current_best_accuracy = 0.0
for epoch in range(EPOCH):
    print(f'\n================= EPOCH {epoch} =================')
    # ######### TRAINING ######################################################################
    # ######### TRAINING ######################################################################
    # ######### TRAINING ######################################################################
    # ######### TRAINING ######################################################################
    # ######### TRAINING ######################################################################
    # ######### TRAINING ######################################################################
    # ######### TRAINING ######################################################################
    dram_address_training_start = dram_address_training_start_next
    dram_address_training_last = dram_address_training_start + tr_samples*DRAM_ADDRESS_INTERVAL_ONE_SAMPLE - 8
    if (dram_address_training_last == dram_address_training_start_last_origin):
        dram_address_training_start_next = dram_address_training_start_origin
    else:
        dram_address_training_start_next = dram_address_training_start + tr_samples*DRAM_ADDRESS_INTERVAL_ONE_SAMPLE

    # print(f'######### P_STATE_08_ASIC_CONFIG_DONE mode ######################################################################')
    # ######### P_STATE_08_ASIC_CONFIG_DONE mode ######################################################################

    # print(f'\nDRAM READ ADDRESS CONFIG!!!!!!!!!!!!')
    # print(f'dram_address_training_start: {dram_address_training_start:,}')
    # print(f'dram_address_training_last: {dram_address_training_last:,}')
    fpga.SetWireInValue(0x01, signed_encoding_32bit(dram_address_training_start)) # dram READ address
    fpga.ActivateTriggerIn(0x40, 30)
    fpga.SetWireInValue(0x01, signed_encoding_32bit(dram_address_training_last)) # dram READ address last
    fpga.ActivateTriggerIn(0x40, 30)
    fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
    fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐



    # print('\n\ndram address 잘 드갔나?')
    # print('dram_address_read_start')
    fpga.SetWireInValue(0x01, signed_encoding_32bit(10))
    ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    # print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

    # print('dram_address_read_last')
    fpga.SetWireInValue(0x01, signed_encoding_32bit(11))
    ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    # print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
    # print('\n')
    fpga.SetWireInValue(0x01, signed_encoding_32bit(0))


    THIS_TRY_SAMPLES = 1 * tr_samples
    fpga.SetWireInValue(0x01, signed_encoding_32bit(THIS_TRY_SAMPLES)) 
    fpga.ActivateTriggerIn(0x40, 26)
    fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
    fpga.CheckTriggered(0x60, 1, timeout=5.0) 

    fpga.SetWireInValue(0x01, signed_encoding_32bit(2))
    ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
    # print(f'sample수 삽입 확인 = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')


    fpga.SetWireInValue(0x01, signed_encoding_32bit(18))
    ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
    # print(f'wirein18로 디버깅 {bin(ep20wireout)} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

    # ######### P_STATE_08_ASIC_CONFIG_DONE mode ######################################################################








    # print('')
    # print('')
    # print('')
    # print('')














    # print(f'######### P_STATE_11_ASIC_TRAINING_QUEUING mode ######################################################################')
    # ######### P_STATE_11_ASIC_TRAINING_QUEUING mode ######################################################################

    # print(f'\nQUEUING 시작')
    fpga.ActivateTriggerIn(0x40, 0) # 0 training, 1 inference
    fpga.CheckTriggered(0x60, 1, timeout=5.0) # queuing 다 됐나
    # print(f'QUEUING 완료\n')


    # ASIC start ready 확인
    fpga.ActivateTriggerIn(0x40, 28)
    fpga.CheckTriggered(0x60, 1, timeout=1.0)
    ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    # print(f'ASIC start ready 확인 = WireOut 0x20 value: {ep20wireout} (1이면 준비된 것) unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
    assert ep20wireout == 1, "ASIC start 준비가 안된 상태임"
    # ######### P_STATE_11_ASIC_TRAINING_QUEUING mode ######################################################################













    # print('')
    # print('')
    # print('')
    # print('')



    # print(f'######### P_STATE_12_ASIC_TRAINING_PROCESSING mode ######################################################################')
    # ######### P_STATE_12_ASIC_TRAINING_PROCESSING mode ######################################################################

    # print(f'\nPROCESSING 시작')
    time_start = time.time()
    fpga.ActivateTriggerIn(0x40, 0) # GO PROCESSING
    fpga.CheckTriggered(0x60, 1, timeout=1000.0) # processing완료
    time_end = time.time()
    # print(f'\nPROCESSING 종료, 걸린 시간: {time_end - time_start:.2f} seconds\n')



    # sample_num_executed_from_a
    fpga.ActivateTriggerIn(0x40, 22)
    fpga.CheckTriggered(0x60, 1, timeout=1.0)
    fpga.SetWireInValue(0x01, signed_encoding_32bit(19))
    samples_executed_from_a = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    assert samples_executed_from_a == THIS_TRY_SAMPLES, f"처리한 sample 수가 삽입한 수랑 다름! ep20wireout: {ep20wireout:,} vs THIS_TRY_SAMPLES: {THIS_TRY_SAMPLES:,}"
    fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
    # print(f'sample_num_executed_from_a: {ep20wireout:,}')

    # ######### P_STATE_12_ASIC_TRAINING_PROCESSING mode ######################################################################


    # @ P_STATE_08_ASIC_CONFIG_DONE
    # print(f'\PROCESSING TIME 세팅 하기')
    fpga.ActivateTriggerIn(0x40, 23) # GO PROCESSING
    fpga.CheckTriggered(0x60, 1, timeout=1.0) # processing완료

    fpga.SetWireInValue(0x01, signed_encoding_32bit(16))
    PROCESSING_CLK_CNT_LOW32BIT = fpga.GetWireOutValue(0x20) # signed 아니니까 signed decoding하지마
    fpga.SetWireInValue(0x01, signed_encoding_32bit(17))
    PROCESSING_CLK_CNT_HIGH32BIT = fpga.GetWireOutValue(0x20) # signed 아니니까 signed decoding하지마
    fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
    TOTAL_PROCESSING_CLK_CNT = (PROCESSING_CLK_CNT_HIGH32BIT * (2**32)) + PROCESSING_CLK_CNT_LOW32BIT
    # print(f'총 PROCESSING CYCLE 수: {TOTAL_PROCESSING_CLK_CNT:,} cycles')
    # print(f'PROCESSING CYCLE / SAMPLE: {TOTAL_PROCESSING_CLK_CNT/samples_executed_from_a:.2f} cycles')
    ASIC_FREQUENCY_MHZ = 20
    # print(f'ASIC {ASIC_FREQUENCY_MHZ}MHz라면 샘플 당 걸리는 시간: {(TOTAL_PROCESSING_CLK_CNT/samples_executed_from_a) * (1000/ASIC_FREQUENCY_MHZ) * 0.001:.2f} us')






























    # ######### INFERENCE ######################################################################
    # ######### INFERENCE ######################################################################
    # ######### INFERENCE ######################################################################
    # ######### INFERENCE ######################################################################
    # ######### INFERENCE ######################################################################
    # ######### INFERENCE ######################################################################
    # ######### INFERENCE ######################################################################
    # ######### INFERENCE ######################################################################
    # ######### INFERENCE ######################################################################
    # ######### INFERENCE ######################################################################
    # ######### INFERENCE ######################################################################



    # print(f'######### P_STATE_08_ASIC_CONFIG_DONE mode ######################################################################')
    # ######### P_STATE_08_ASIC_CONFIG_DONE mode ######################################################################

    # print(f'\nDRAM READ ADDRESS CONFIG!!!!!!!!!!!!')
    # print(f'dram_address_inference_start: {dram_address_inference_start:,}')
    # print(f'dram_address_inference_last: {dram_address_inference_last:,}')
    fpga.SetWireInValue(0x01, signed_encoding_32bit(dram_address_inference_start)) # dram READ address
    fpga.ActivateTriggerIn(0x40, 30)
    fpga.SetWireInValue(0x01, signed_encoding_32bit(dram_address_inference_last)) # dram READ address last
    fpga.ActivateTriggerIn(0x40, 30)
    fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
    fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐



    # print('\n\ndram address 잘 드갔나?')
    # print('dram_address_read_start')
    fpga.SetWireInValue(0x01, signed_encoding_32bit(10))
    ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    # print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')

    # print('dram_address_read_last')
    fpga.SetWireInValue(0x01, signed_encoding_32bit(11))
    ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    # print(f'value = WireOut 0x20 value: {ep20wireout} unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
    # print('\n')
    fpga.SetWireInValue(0x01, signed_encoding_32bit(0))



    THIS_TRY_SAMPLES = 1 * inf_samples
    # print(f'\nsample 수 삽입 (inference epochs x inference samples per epoch) {EPOCH} X {inf_samples:,} = {THIS_TRY_SAMPLES:,}')
    fpga.SetWireInValue(0x01, signed_encoding_32bit(THIS_TRY_SAMPLES))
    fpga.ActivateTriggerIn(0x40, 26)
    fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
    fpga.CheckTriggered(0x60, 1, timeout=1.0) # config 다됐냐

    # ######### P_STATE_08_ASIC_CONFIG_DONE mode ######################################################################








    # print('')
    # print('')
    # print('')
    # print('')














    print(f'######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################')
    # ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################

    # print(f'\nQUEUING 시작')
    fpga.ActivateTriggerIn(0x40, 1) # 0 training, 1 inference
    fpga.CheckTriggered(0x60, 1, timeout=5.0) # queuing 다 됐나
    # print(f'QUEUING 완료\n')


    # ASIC start ready 확인
    fpga.ActivateTriggerIn(0x40, 28)
    fpga.CheckTriggered(0x60, 1, timeout=1.0)
    ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    # print(f'ASIC start ready 확인 = WireOut 0x20 value: {ep20wireout} (1이면 준비된 것) unsigned hex: {hex(fpga.GetWireOutValue(0x20))}')
    assert ep20wireout == 1, "ASIC start 준비가 안된 상태임"
    # ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################


    # print('')
    # print('')
    # print('')
    # print('')



    # print(f'######### P_STATE_10_ASIC_INFERENCE_PROCESSING mode ######################################################################')
    # ######### P_STATE_10_ASIC_INFERENCE_PROCESSING mode ######################################################################

    # print(f'\nPROCESSING 시작')
    time_start = time.time()
    fpga.ActivateTriggerIn(0x40, 0) # GO PROCESSING
    fpga.CheckTriggered(0x60, 1, timeout=60.0) # processing완료
    time_end = time.time()
    # print(f'\nPROCESSING 종료, 걸린 시간: {time_end - time_start:.2f} seconds\n')
    # sample_num_executed_from_a
    fpga.ActivateTriggerIn(0x40, 22)
    fpga.CheckTriggered(0x60, 1, timeout=1.0)
    fpga.SetWireInValue(0x01, signed_encoding_32bit(19))
    samples_executed_from_a = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    assert samples_executed_from_a == THIS_TRY_SAMPLES, f"처리한 sample 수가 삽입한 수랑 다름! ep20wireout: {ep20wireout:,} vs THIS_TRY_SAMPLES: {THIS_TRY_SAMPLES:,}"
    fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
    # print(f'sample_num_executed_from_a: {ep20wireout:,}')

    # @ P_STATE_08_ASIC_CONFIG_DONE
    # print(f'\n결과 세팅 하기')
    fpga.ActivateTriggerIn(0x40, 25) # GO PROCESSING
    fpga.CheckTriggered(0x60, 1, timeout=1.0) # processing완료

    fpga.SetWireInValue(0x01, signed_encoding_32bit(13))
    ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    correct_sample_num = ep20wireout
    fpga.SetWireInValue(0x01, signed_encoding_32bit(14))
    ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    wrong_sample_num = ep20wireout
    fpga.SetWireInValue(0x01, signed_encoding_32bit(15))
    ep20wireout = signed_decoding_32bit(fpga.GetWireOutValue(0x20))
    total_inference_sample_num = ep20wireout
    assert total_inference_sample_num == THIS_TRY_SAMPLES, f"처리한 sample 수가 삽입한 수랑 다름! ep20wireout: {ep20wireout:,} vs THIS_TRY_SAMPLES: {THIS_TRY_SAMPLES:,}"

    fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
    assert correct_sample_num + wrong_sample_num == total_inference_sample_num, "맞은거 + 틀린거 != 전체 샘플 수"
    print(f'결과: correct_sample_num: {correct_sample_num}, wrong_sample_num: {wrong_sample_num}, total_inference_sample_num: {total_inference_sample_num}')
    print(f'정확도: {(correct_sample_num/total_inference_sample_num)*100:.2f} %')
    accuracy_list.append((correct_sample_num/total_inference_sample_num)*100)
    current_best_accuracy = max(current_best_accuracy, (correct_sample_num/total_inference_sample_num)*100)
    print(f'현재 베스트 정확도: {current_best_accuracy:.2f} %')


    # @ P_STATE_08_ASIC_CONFIG_DONE
    # print(f'\PROCESSING TIME 세팅 하기')
    fpga.ActivateTriggerIn(0x40, 23)
    fpga.CheckTriggered(0x60, 1, timeout=1.0)

    fpga.SetWireInValue(0x01, signed_encoding_32bit(16))
    PROCESSING_CLK_CNT_LOW32BIT = fpga.GetWireOutValue(0x20) # signed 아니니까 signed decoding하지마
    fpga.SetWireInValue(0x01, signed_encoding_32bit(17))
    PROCESSING_CLK_CNT_HIGH32BIT = fpga.GetWireOutValue(0x20) # signed 아니니까 signed decoding하지마
    fpga.SetWireInValue(0x01, signed_encoding_32bit(0))
    TOTAL_PROCESSING_CLK_CNT = (PROCESSING_CLK_CNT_HIGH32BIT * (2**32)) + PROCESSING_CLK_CNT_LOW32BIT
    print(f'총 PROCESSING CYCLE 수: {TOTAL_PROCESSING_CLK_CNT:,} cycles')
    print(f'PROCESSING CYCLE / SAMPLE: {TOTAL_PROCESSING_CLK_CNT/total_inference_sample_num:.2f} cycles')
    ASIC_FREQUENCY_MHZ = 20
    print(f'ASIC {ASIC_FREQUENCY_MHZ}MHz라면 샘플 당 걸리는 시간: {(TOTAL_PROCESSING_CLK_CNT/total_inference_sample_num) * (1000/ASIC_FREQUENCY_MHZ) * 0.001:.2f} us')



print(f'DATASET {HYPER_DATASET} TRAINING+INFERENCE ALL EPOCHS DONE!!!!!!!!!!!!')
print('accuracy_list:', accuracy_list)
print(f'베스트 정확도: {max(accuracy_list):.2f} % at epoch {accuracy_list.index(max(accuracy_list))}')
# Out:
# ================= EPOCH 0 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9120, wrong_sample_num: 880, total_inference_sample_num: 10000
# 정확도: 91.20 %
# 현재 베스트 정확도: 91.20 %
# 총 PROCESSING CYCLE 수: 2,089,257 cycles
# PROCESSING CYCLE / SAMPLE: 208.93 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 10.45 us
#
# ================= EPOCH 1 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 8614, wrong_sample_num: 1386, total_inference_sample_num: 10000
# 정확도: 86.14 %
# 현재 베스트 정확도: 91.20 %
# 총 PROCESSING CYCLE 수: 2,176,243 cycles
# PROCESSING CYCLE / SAMPLE: 217.62 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 10.88 us
#
# ================= EPOCH 2 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9160, wrong_sample_num: 840, total_inference_sample_num: 10000
# 정확도: 91.60 %
# 현재 베스트 정확도: 91.60 %
# 총 PROCESSING CYCLE 수: 2,203,711 cycles
# PROCESSING CYCLE / SAMPLE: 220.37 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 11.02 us
#
# ================= EPOCH 3 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9212, wrong_sample_num: 788, total_inference_sample_num: 10000
# 정확도: 92.12 %
# 현재 베스트 정확도: 92.12 %
# 총 PROCESSING CYCLE 수: 2,246,673 cycles
# PROCESSING CYCLE / SAMPLE: 224.67 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 11.23 us
#
# ================= EPOCH 4 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9124, wrong_sample_num: 876, total_inference_sample_num: 10000
# 정확도: 91.24 %
# 현재 베스트 정확도: 92.12 %
# 총 PROCESSING CYCLE 수: 2,369,822 cycles
# PROCESSING CYCLE / SAMPLE: 236.98 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 11.85 us
#
# ================= EPOCH 5 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 8533, wrong_sample_num: 1467, total_inference_sample_num: 10000
# 정확도: 85.33 %
# 현재 베스트 정확도: 92.12 %
# 총 PROCESSING CYCLE 수: 2,360,713 cycles
# PROCESSING CYCLE / SAMPLE: 236.07 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 11.80 us
#
# ================= EPOCH 6 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9282, wrong_sample_num: 718, total_inference_sample_num: 10000
# 정확도: 92.82 %
# 현재 베스트 정확도: 92.82 %
# 총 PROCESSING CYCLE 수: 2,332,764 cycles
# PROCESSING CYCLE / SAMPLE: 233.28 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 11.66 us
#
# ================= EPOCH 7 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9132, wrong_sample_num: 868, total_inference_sample_num: 10000
# 정확도: 91.32 %
# 현재 베스트 정확도: 92.82 %
# 총 PROCESSING CYCLE 수: 2,420,862 cycles
# PROCESSING CYCLE / SAMPLE: 242.09 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 12.10 us
#
# ================= EPOCH 8 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9289, wrong_sample_num: 711, total_inference_sample_num: 10000
# 정확도: 92.89 %
# 현재 베스트 정확도: 92.89 %
# 총 PROCESSING CYCLE 수: 2,383,063 cycles
# PROCESSING CYCLE / SAMPLE: 238.31 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 11.92 us
#
# ================= EPOCH 9 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9116, wrong_sample_num: 884, total_inference_sample_num: 10000
# 정확도: 91.16 %
# 현재 베스트 정확도: 92.89 %
# 총 PROCESSING CYCLE 수: 2,487,500 cycles
# PROCESSING CYCLE / SAMPLE: 248.75 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 12.44 us
#
# ================= EPOCH 10 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9348, wrong_sample_num: 652, total_inference_sample_num: 10000
# 정확도: 93.48 %
# 현재 베스트 정확도: 93.48 %
# 총 PROCESSING CYCLE 수: 2,484,516 cycles
# PROCESSING CYCLE / SAMPLE: 248.45 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 12.42 us
#
# ================= EPOCH 11 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9150, wrong_sample_num: 850, total_inference_sample_num: 10000
# 정확도: 91.50 %
# 현재 베스트 정확도: 93.48 %
# 총 PROCESSING CYCLE 수: 2,470,038 cycles
# PROCESSING CYCLE / SAMPLE: 247.00 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 12.35 us
#
# ================= EPOCH 12 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9415, wrong_sample_num: 585, total_inference_sample_num: 10000
# 정확도: 94.15 %
# 현재 베스트 정확도: 94.15 %
# 총 PROCESSING CYCLE 수: 2,447,802 cycles
# PROCESSING CYCLE / SAMPLE: 244.78 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 12.24 us
#
# ================= EPOCH 13 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9398, wrong_sample_num: 602, total_inference_sample_num: 10000
# 정확도: 93.98 %
# 현재 베스트 정확도: 94.15 %
# 총 PROCESSING CYCLE 수: 2,499,457 cycles
# PROCESSING CYCLE / SAMPLE: 249.95 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 12.50 us
#
# ================= EPOCH 14 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9278, wrong_sample_num: 722, total_inference_sample_num: 10000
# 정확도: 92.78 %
# 현재 베스트 정확도: 94.15 %
# 총 PROCESSING CYCLE 수: 2,627,814 cycles
# PROCESSING CYCLE / SAMPLE: 262.78 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 13.14 us
#
# ================= EPOCH 15 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9387, wrong_sample_num: 613, total_inference_sample_num: 10000
# 정확도: 93.87 %
# 현재 베스트 정확도: 94.15 %
# 총 PROCESSING CYCLE 수: 2,667,116 cycles
# PROCESSING CYCLE / SAMPLE: 266.71 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 13.34 us
#
# ================= EPOCH 16 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9165, wrong_sample_num: 835, total_inference_sample_num: 10000
# 정확도: 91.65 %
# 현재 베스트 정확도: 94.15 %
# 총 PROCESSING CYCLE 수: 2,780,498 cycles
# PROCESSING CYCLE / SAMPLE: 278.05 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 13.90 us
#
# ================= EPOCH 17 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 8845, wrong_sample_num: 1155, total_inference_sample_num: 10000
# 정확도: 88.45 %
# 현재 베스트 정확도: 94.15 %
# 총 PROCESSING CYCLE 수: 2,664,160 cycles
# PROCESSING CYCLE / SAMPLE: 266.42 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 13.32 us
#
# ================= EPOCH 18 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9056, wrong_sample_num: 944, total_inference_sample_num: 10000
# 정확도: 90.56 %
# 현재 베스트 정확도: 94.15 %
# 총 PROCESSING CYCLE 수: 2,644,543 cycles
# PROCESSING CYCLE / SAMPLE: 264.45 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 13.22 us
#
# ================= EPOCH 19 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9435, wrong_sample_num: 565, total_inference_sample_num: 10000
# 정확도: 94.35 %
# 현재 베스트 정확도: 94.35 %
# 총 PROCESSING CYCLE 수: 2,695,265 cycles
# PROCESSING CYCLE / SAMPLE: 269.53 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 13.48 us
#
# ================= EPOCH 20 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9346, wrong_sample_num: 654, total_inference_sample_num: 10000
# 정확도: 93.46 %
# 현재 베스트 정확도: 94.35 %
# 총 PROCESSING CYCLE 수: 2,785,424 cycles
# PROCESSING CYCLE / SAMPLE: 278.54 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 13.93 us
#
# ================= EPOCH 21 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9481, wrong_sample_num: 519, total_inference_sample_num: 10000
# 정확도: 94.81 %
# 현재 베스트 정확도: 94.81 %
# 총 PROCESSING CYCLE 수: 2,698,402 cycles
# PROCESSING CYCLE / SAMPLE: 269.84 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 13.49 us
#
# ================= EPOCH 22 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9408, wrong_sample_num: 592, total_inference_sample_num: 10000
# 정확도: 94.08 %
# 현재 베스트 정확도: 94.81 %
# 총 PROCESSING CYCLE 수: 2,804,935 cycles
# PROCESSING CYCLE / SAMPLE: 280.49 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 14.02 us
#
# ================= EPOCH 23 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9433, wrong_sample_num: 567, total_inference_sample_num: 10000
# 정확도: 94.33 %
# 현재 베스트 정확도: 94.81 %
# 총 PROCESSING CYCLE 수: 2,768,192 cycles
# PROCESSING CYCLE / SAMPLE: 276.82 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 13.84 us
#
# ================= EPOCH 24 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9471, wrong_sample_num: 529, total_inference_sample_num: 10000
# 정확도: 94.71 %
# 현재 베스트 정확도: 94.81 %
# 총 PROCESSING CYCLE 수: 2,819,284 cycles
# PROCESSING CYCLE / SAMPLE: 281.93 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 14.10 us
#
# ================= EPOCH 25 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9302, wrong_sample_num: 698, total_inference_sample_num: 10000
# 정확도: 93.02 %
# 현재 베스트 정확도: 94.81 %
# 총 PROCESSING CYCLE 수: 2,824,626 cycles
# PROCESSING CYCLE / SAMPLE: 282.46 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 14.12 us
#
# ================= EPOCH 26 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9482, wrong_sample_num: 518, total_inference_sample_num: 10000
# 정확도: 94.82 %
# 현재 베스트 정확도: 94.82 %
# 총 PROCESSING CYCLE 수: 2,914,861 cycles
# PROCESSING CYCLE / SAMPLE: 291.49 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 14.57 us
#
# ================= EPOCH 27 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9437, wrong_sample_num: 563, total_inference_sample_num: 10000
# 정확도: 94.37 %
# 현재 베스트 정확도: 94.82 %
# 총 PROCESSING CYCLE 수: 2,980,778 cycles
# PROCESSING CYCLE / SAMPLE: 298.08 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 14.90 us
#
# ================= EPOCH 28 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9510, wrong_sample_num: 490, total_inference_sample_num: 10000
# 정확도: 95.10 %
# 현재 베스트 정확도: 95.10 %
# 총 PROCESSING CYCLE 수: 2,888,998 cycles
# PROCESSING CYCLE / SAMPLE: 288.90 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 14.44 us
#
# ================= EPOCH 29 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9557, wrong_sample_num: 443, total_inference_sample_num: 10000
# 정확도: 95.57 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,044,276 cycles
# PROCESSING CYCLE / SAMPLE: 304.43 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 15.22 us
#
# ================= EPOCH 30 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9457, wrong_sample_num: 543, total_inference_sample_num: 10000
# 정확도: 94.57 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,076,102 cycles
# PROCESSING CYCLE / SAMPLE: 307.61 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 15.38 us
#
# ================= EPOCH 31 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9371, wrong_sample_num: 629, total_inference_sample_num: 10000
# 정확도: 93.71 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,024,711 cycles
# PROCESSING CYCLE / SAMPLE: 302.47 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 15.12 us
#
# ================= EPOCH 32 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9452, wrong_sample_num: 548, total_inference_sample_num: 10000
# 정확도: 94.52 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 2,956,147 cycles
# PROCESSING CYCLE / SAMPLE: 295.61 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 14.78 us
#
# ================= EPOCH 33 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9464, wrong_sample_num: 536, total_inference_sample_num: 10000
# 정확도: 94.64 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,061,227 cycles
# PROCESSING CYCLE / SAMPLE: 306.12 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 15.31 us
#
# ================= EPOCH 34 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9372, wrong_sample_num: 628, total_inference_sample_num: 10000
# 정확도: 93.72 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,025,524 cycles
# PROCESSING CYCLE / SAMPLE: 302.55 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 15.13 us
#
# ================= EPOCH 35 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9511, wrong_sample_num: 489, total_inference_sample_num: 10000
# 정확도: 95.11 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,062,966 cycles
# PROCESSING CYCLE / SAMPLE: 306.30 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 15.31 us
#
# ================= EPOCH 36 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9510, wrong_sample_num: 490, total_inference_sample_num: 10000
# 정확도: 95.10 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,097,372 cycles
# PROCESSING CYCLE / SAMPLE: 309.74 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 15.49 us
#
# ================= EPOCH 37 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9260, wrong_sample_num: 740, total_inference_sample_num: 10000
# 정확도: 92.60 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,062,635 cycles
# PROCESSING CYCLE / SAMPLE: 306.26 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 15.31 us
#
# ================= EPOCH 38 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9171, wrong_sample_num: 829, total_inference_sample_num: 10000
# 정확도: 91.71 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,025,730 cycles
# PROCESSING CYCLE / SAMPLE: 302.57 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 15.13 us
#
# ================= EPOCH 39 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9545, wrong_sample_num: 455, total_inference_sample_num: 10000
# 정확도: 95.45 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,136,599 cycles
# PROCESSING CYCLE / SAMPLE: 313.66 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 15.68 us
#
# ================= EPOCH 40 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9324, wrong_sample_num: 676, total_inference_sample_num: 10000
# 정확도: 93.24 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,116,336 cycles
# PROCESSING CYCLE / SAMPLE: 311.63 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 15.58 us
#
# ================= EPOCH 41 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9191, wrong_sample_num: 809, total_inference_sample_num: 10000
# 정확도: 91.91 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,102,566 cycles
# PROCESSING CYCLE / SAMPLE: 310.26 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 15.51 us
#
# ================= EPOCH 42 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9541, wrong_sample_num: 459, total_inference_sample_num: 10000
# 정확도: 95.41 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,264,773 cycles
# PROCESSING CYCLE / SAMPLE: 326.48 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.32 us
#
# ================= EPOCH 43 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9496, wrong_sample_num: 504, total_inference_sample_num: 10000
# 정확도: 94.96 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,160,925 cycles
# PROCESSING CYCLE / SAMPLE: 316.09 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 15.80 us
#
# ================= EPOCH 44 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9340, wrong_sample_num: 660, total_inference_sample_num: 10000
# 정확도: 93.40 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,271,364 cycles
# PROCESSING CYCLE / SAMPLE: 327.14 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.36 us
#
# ================= EPOCH 45 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9516, wrong_sample_num: 484, total_inference_sample_num: 10000
# 정확도: 95.16 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,221,627 cycles
# PROCESSING CYCLE / SAMPLE: 322.16 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.11 us
#
# ================= EPOCH 46 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9378, wrong_sample_num: 622, total_inference_sample_num: 10000
# 정확도: 93.78 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,223,528 cycles
# PROCESSING CYCLE / SAMPLE: 322.35 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.12 us
#
# ================= EPOCH 47 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9392, wrong_sample_num: 608, total_inference_sample_num: 10000
# 정확도: 93.92 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,270,196 cycles
# PROCESSING CYCLE / SAMPLE: 327.02 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.35 us
#
# ================= EPOCH 48 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9420, wrong_sample_num: 580, total_inference_sample_num: 10000
# 정확도: 94.20 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,329,687 cycles
# PROCESSING CYCLE / SAMPLE: 332.97 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.65 us
#
# ================= EPOCH 49 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9477, wrong_sample_num: 523, total_inference_sample_num: 10000
# 정확도: 94.77 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,252,550 cycles
# PROCESSING CYCLE / SAMPLE: 325.25 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.26 us
#
# ================= EPOCH 50 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9400, wrong_sample_num: 600, total_inference_sample_num: 10000
# 정확도: 94.00 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,351,679 cycles
# PROCESSING CYCLE / SAMPLE: 335.17 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.76 us
#
# ================= EPOCH 51 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9212, wrong_sample_num: 788, total_inference_sample_num: 10000
# 정확도: 92.12 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,309,369 cycles
# PROCESSING CYCLE / SAMPLE: 330.94 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.55 us
#
# ================= EPOCH 52 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9471, wrong_sample_num: 529, total_inference_sample_num: 10000
# 정확도: 94.71 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,247,697 cycles
# PROCESSING CYCLE / SAMPLE: 324.77 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.24 us
#
# ================= EPOCH 53 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9264, wrong_sample_num: 736, total_inference_sample_num: 10000
# 정확도: 92.64 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,366,954 cycles
# PROCESSING CYCLE / SAMPLE: 336.70 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.83 us
#
# ================= EPOCH 54 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9489, wrong_sample_num: 511, total_inference_sample_num: 10000
# 정확도: 94.89 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,255,481 cycles
# PROCESSING CYCLE / SAMPLE: 325.55 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.28 us
#
# ================= EPOCH 55 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9181, wrong_sample_num: 819, total_inference_sample_num: 10000
# 정확도: 91.81 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,329,759 cycles
# PROCESSING CYCLE / SAMPLE: 332.98 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.65 us
#
# ================= EPOCH 56 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9444, wrong_sample_num: 556, total_inference_sample_num: 10000
# 정확도: 94.44 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,395,001 cycles
# PROCESSING CYCLE / SAMPLE: 339.50 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.98 us
#
# ================= EPOCH 57 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9526, wrong_sample_num: 474, total_inference_sample_num: 10000
# 정확도: 95.26 %
# 현재 베스트 정확도: 95.57 %
# 총 PROCESSING CYCLE 수: 3,314,982 cycles
# PROCESSING CYCLE / SAMPLE: 331.50 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.57 us
#
# ================= EPOCH 58 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9585, wrong_sample_num: 415, total_inference_sample_num: 10000
# 정확도: 95.85 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,229,761 cycles
# PROCESSING CYCLE / SAMPLE: 322.98 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.15 us
#
# ================= EPOCH 59 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9398, wrong_sample_num: 602, total_inference_sample_num: 10000
# 정확도: 93.98 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,266,389 cycles
# PROCESSING CYCLE / SAMPLE: 326.64 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.33 us
#
# ================= EPOCH 60 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9505, wrong_sample_num: 495, total_inference_sample_num: 10000
# 정확도: 95.05 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,342,655 cycles
# PROCESSING CYCLE / SAMPLE: 334.27 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.71 us
#
# ================= EPOCH 61 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9521, wrong_sample_num: 479, total_inference_sample_num: 10000
# 정확도: 95.21 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,310,543 cycles
# PROCESSING CYCLE / SAMPLE: 331.05 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.55 us
#
# ================= EPOCH 62 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9446, wrong_sample_num: 554, total_inference_sample_num: 10000
# 정확도: 94.46 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,406,107 cycles
# PROCESSING CYCLE / SAMPLE: 340.61 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.03 us
#
# ================= EPOCH 63 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9512, wrong_sample_num: 488, total_inference_sample_num: 10000
# 정확도: 95.12 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,310,700 cycles
# PROCESSING CYCLE / SAMPLE: 331.07 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.55 us
#
# ================= EPOCH 64 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9522, wrong_sample_num: 478, total_inference_sample_num: 10000
# 정확도: 95.22 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,307,559 cycles
# PROCESSING CYCLE / SAMPLE: 330.76 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.54 us
#
# ================= EPOCH 65 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9566, wrong_sample_num: 434, total_inference_sample_num: 10000
# 정확도: 95.66 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,229,125 cycles
# PROCESSING CYCLE / SAMPLE: 322.91 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.15 us
#
# ================= EPOCH 66 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9471, wrong_sample_num: 529, total_inference_sample_num: 10000
# 정확도: 94.71 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,256,943 cycles
# PROCESSING CYCLE / SAMPLE: 325.69 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.28 us
#
# ================= EPOCH 67 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9262, wrong_sample_num: 738, total_inference_sample_num: 10000
# 정확도: 92.62 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,291,235 cycles
# PROCESSING CYCLE / SAMPLE: 329.12 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.46 us
#
# ================= EPOCH 68 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9454, wrong_sample_num: 546, total_inference_sample_num: 10000
# 정확도: 94.54 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,335,232 cycles
# PROCESSING CYCLE / SAMPLE: 333.52 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.68 us
#
# ================= EPOCH 69 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9362, wrong_sample_num: 638, total_inference_sample_num: 10000
# 정확도: 93.62 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,311,199 cycles
# PROCESSING CYCLE / SAMPLE: 331.12 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.56 us
#
# ================= EPOCH 70 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9387, wrong_sample_num: 613, total_inference_sample_num: 10000
# 정확도: 93.87 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,305,222 cycles
# PROCESSING CYCLE / SAMPLE: 330.52 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.53 us
#
# ================= EPOCH 71 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9493, wrong_sample_num: 507, total_inference_sample_num: 10000
# 정확도: 94.93 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,264,236 cycles
# PROCESSING CYCLE / SAMPLE: 326.42 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.32 us
#
# ================= EPOCH 72 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9371, wrong_sample_num: 629, total_inference_sample_num: 10000
# 정확도: 93.71 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,199,429 cycles
# PROCESSING CYCLE / SAMPLE: 319.94 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.00 us
#
# ================= EPOCH 73 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9467, wrong_sample_num: 533, total_inference_sample_num: 10000
# 정확도: 94.67 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,267,102 cycles
# PROCESSING CYCLE / SAMPLE: 326.71 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.34 us
#
# ================= EPOCH 74 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9559, wrong_sample_num: 441, total_inference_sample_num: 10000
# 정확도: 95.59 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,267,359 cycles
# PROCESSING CYCLE / SAMPLE: 326.74 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.34 us
#
# ================= EPOCH 75 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9360, wrong_sample_num: 640, total_inference_sample_num: 10000
# 정확도: 93.60 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,213,804 cycles
# PROCESSING CYCLE / SAMPLE: 321.38 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.07 us
#
# ================= EPOCH 76 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9523, wrong_sample_num: 477, total_inference_sample_num: 10000
# 정확도: 95.23 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,265,456 cycles
# PROCESSING CYCLE / SAMPLE: 326.55 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.33 us
#
# ================= EPOCH 77 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9530, wrong_sample_num: 470, total_inference_sample_num: 10000
# 정확도: 95.30 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,243,131 cycles
# PROCESSING CYCLE / SAMPLE: 324.31 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.22 us
#
# ================= EPOCH 78 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9241, wrong_sample_num: 759, total_inference_sample_num: 10000
# 정확도: 92.41 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,251,369 cycles
# PROCESSING CYCLE / SAMPLE: 325.14 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.26 us
#
# ================= EPOCH 79 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9573, wrong_sample_num: 427, total_inference_sample_num: 10000
# 정확도: 95.73 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,340,987 cycles
# PROCESSING CYCLE / SAMPLE: 334.10 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.70 us
#
# ================= EPOCH 80 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9433, wrong_sample_num: 567, total_inference_sample_num: 10000
# 정확도: 94.33 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,326,864 cycles
# PROCESSING CYCLE / SAMPLE: 332.69 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.63 us
#
# ================= EPOCH 81 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9463, wrong_sample_num: 537, total_inference_sample_num: 10000
# 정확도: 94.63 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,331,888 cycles
# PROCESSING CYCLE / SAMPLE: 333.19 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.66 us
#
# ================= EPOCH 82 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9527, wrong_sample_num: 473, total_inference_sample_num: 10000
# 정확도: 95.27 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,345,309 cycles
# PROCESSING CYCLE / SAMPLE: 334.53 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.73 us
#
# ================= EPOCH 83 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9540, wrong_sample_num: 460, total_inference_sample_num: 10000
# 정확도: 95.40 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,333,339 cycles
# PROCESSING CYCLE / SAMPLE: 333.33 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.67 us
#
# ================= EPOCH 84 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9469, wrong_sample_num: 531, total_inference_sample_num: 10000
# 정확도: 94.69 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,366,226 cycles
# PROCESSING CYCLE / SAMPLE: 336.62 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.83 us
#
# ================= EPOCH 85 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9442, wrong_sample_num: 558, total_inference_sample_num: 10000
# 정확도: 94.42 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,273,013 cycles
# PROCESSING CYCLE / SAMPLE: 327.30 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.37 us
#
# ================= EPOCH 86 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9553, wrong_sample_num: 447, total_inference_sample_num: 10000
# 정확도: 95.53 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,258,254 cycles
# PROCESSING CYCLE / SAMPLE: 325.83 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.29 us
#
# ================= EPOCH 87 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9510, wrong_sample_num: 490, total_inference_sample_num: 10000
# 정확도: 95.10 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,355,113 cycles
# PROCESSING CYCLE / SAMPLE: 335.51 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.78 us
#
# ================= EPOCH 88 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9465, wrong_sample_num: 535, total_inference_sample_num: 10000
# 정확도: 94.65 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,279,312 cycles
# PROCESSING CYCLE / SAMPLE: 327.93 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.40 us
#
# ================= EPOCH 89 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9519, wrong_sample_num: 481, total_inference_sample_num: 10000
# 정확도: 95.19 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,298,050 cycles
# PROCESSING CYCLE / SAMPLE: 329.81 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.49 us
#
# ================= EPOCH 90 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9399, wrong_sample_num: 601, total_inference_sample_num: 10000
# 정확도: 93.99 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,265,210 cycles
# PROCESSING CYCLE / SAMPLE: 326.52 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.33 us
#
# ================= EPOCH 91 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9384, wrong_sample_num: 616, total_inference_sample_num: 10000
# 정확도: 93.84 %
# 현재 베스트 정확도: 95.85 %
# 총 PROCESSING CYCLE 수: 3,345,652 cycles
# PROCESSING CYCLE / SAMPLE: 334.57 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.73 us
#
# ================= EPOCH 92 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9595, wrong_sample_num: 405, total_inference_sample_num: 10000
# 정확도: 95.95 %
# 현재 베스트 정확도: 95.95 %
# 총 PROCESSING CYCLE 수: 3,284,671 cycles
# PROCESSING CYCLE / SAMPLE: 328.47 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.42 us
#
# ================= EPOCH 93 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9557, wrong_sample_num: 443, total_inference_sample_num: 10000
# 정확도: 95.57 %
# 현재 베스트 정확도: 95.95 %
# 총 PROCESSING CYCLE 수: 3,290,758 cycles
# PROCESSING CYCLE / SAMPLE: 329.08 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.45 us
#
# ================= EPOCH 94 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9434, wrong_sample_num: 566, total_inference_sample_num: 10000
# 정확도: 94.34 %
# 현재 베스트 정확도: 95.95 %
# 총 PROCESSING CYCLE 수: 3,280,718 cycles
# PROCESSING CYCLE / SAMPLE: 328.07 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.40 us
#
# ================= EPOCH 95 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9610, wrong_sample_num: 390, total_inference_sample_num: 10000
# 정확도: 96.10 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,369,865 cycles
# PROCESSING CYCLE / SAMPLE: 336.99 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.85 us
#
# ================= EPOCH 96 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9559, wrong_sample_num: 441, total_inference_sample_num: 10000
# 정확도: 95.59 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,377,404 cycles
# PROCESSING CYCLE / SAMPLE: 337.74 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.89 us
#
# ================= EPOCH 97 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9412, wrong_sample_num: 588, total_inference_sample_num: 10000
# 정확도: 94.12 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,301,270 cycles
# PROCESSING CYCLE / SAMPLE: 330.13 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.51 us
#
# ================= EPOCH 98 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9533, wrong_sample_num: 467, total_inference_sample_num: 10000
# 정확도: 95.33 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,310,122 cycles
# PROCESSING CYCLE / SAMPLE: 331.01 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.55 us
#
# ================= EPOCH 99 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9484, wrong_sample_num: 516, total_inference_sample_num: 10000
# 정확도: 94.84 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,354,657 cycles
# PROCESSING CYCLE / SAMPLE: 335.47 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.77 us
#
# ================= EPOCH 100 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9507, wrong_sample_num: 493, total_inference_sample_num: 10000
# 정확도: 95.07 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,312,973 cycles
# PROCESSING CYCLE / SAMPLE: 331.30 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.56 us
#
# ================= EPOCH 101 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9374, wrong_sample_num: 626, total_inference_sample_num: 10000
# 정확도: 93.74 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,396,989 cycles
# PROCESSING CYCLE / SAMPLE: 339.70 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.98 us
#
# ================= EPOCH 102 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9572, wrong_sample_num: 428, total_inference_sample_num: 10000
# 정확도: 95.72 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,327,514 cycles
# PROCESSING CYCLE / SAMPLE: 332.75 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.64 us
#
# ================= EPOCH 103 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9560, wrong_sample_num: 440, total_inference_sample_num: 10000
# 정확도: 95.60 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,398,480 cycles
# PROCESSING CYCLE / SAMPLE: 339.85 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.99 us
#
# ================= EPOCH 104 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9556, wrong_sample_num: 444, total_inference_sample_num: 10000
# 정확도: 95.56 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,319,991 cycles
# PROCESSING CYCLE / SAMPLE: 332.00 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.60 us
#
# ================= EPOCH 105 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9570, wrong_sample_num: 430, total_inference_sample_num: 10000
# 정확도: 95.70 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,395,675 cycles
# PROCESSING CYCLE / SAMPLE: 339.57 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.98 us
#
# ================= EPOCH 106 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9544, wrong_sample_num: 456, total_inference_sample_num: 10000
# 정확도: 95.44 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,441,472 cycles
# PROCESSING CYCLE / SAMPLE: 344.15 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.21 us
#
# ================= EPOCH 107 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9529, wrong_sample_num: 471, total_inference_sample_num: 10000
# 정확도: 95.29 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,392,721 cycles
# PROCESSING CYCLE / SAMPLE: 339.27 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.96 us
#
# ================= EPOCH 108 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9584, wrong_sample_num: 416, total_inference_sample_num: 10000
# 정확도: 95.84 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,481,086 cycles
# PROCESSING CYCLE / SAMPLE: 348.11 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.41 us
#
# ================= EPOCH 109 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9432, wrong_sample_num: 568, total_inference_sample_num: 10000
# 정확도: 94.32 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,501,042 cycles
# PROCESSING CYCLE / SAMPLE: 350.10 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.51 us
#
# ================= EPOCH 110 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9528, wrong_sample_num: 472, total_inference_sample_num: 10000
# 정확도: 95.28 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,469,643 cycles
# PROCESSING CYCLE / SAMPLE: 346.96 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.35 us
#
# ================= EPOCH 111 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9155, wrong_sample_num: 845, total_inference_sample_num: 10000
# 정확도: 91.55 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,415,292 cycles
# PROCESSING CYCLE / SAMPLE: 341.53 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.08 us
#
# ================= EPOCH 112 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9538, wrong_sample_num: 462, total_inference_sample_num: 10000
# 정확도: 95.38 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,430,721 cycles
# PROCESSING CYCLE / SAMPLE: 343.07 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.15 us
#
# ================= EPOCH 113 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9337, wrong_sample_num: 663, total_inference_sample_num: 10000
# 정확도: 93.37 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,431,767 cycles
# PROCESSING CYCLE / SAMPLE: 343.18 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.16 us
#
# ================= EPOCH 114 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9476, wrong_sample_num: 524, total_inference_sample_num: 10000
# 정확도: 94.76 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,371,361 cycles
# PROCESSING CYCLE / SAMPLE: 337.14 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 16.86 us
#
# ================= EPOCH 115 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9491, wrong_sample_num: 509, total_inference_sample_num: 10000
# 정확도: 94.91 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,468,355 cycles
# PROCESSING CYCLE / SAMPLE: 346.84 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.34 us
#
# ================= EPOCH 116 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9590, wrong_sample_num: 410, total_inference_sample_num: 10000
# 정확도: 95.90 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,526,812 cycles
# PROCESSING CYCLE / SAMPLE: 352.68 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.63 us
#
# ================= EPOCH 117 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9353, wrong_sample_num: 647, total_inference_sample_num: 10000
# 정확도: 93.53 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,514,317 cycles
# PROCESSING CYCLE / SAMPLE: 351.43 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.57 us
#
# ================= EPOCH 118 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9522, wrong_sample_num: 478, total_inference_sample_num: 10000
# 정확도: 95.22 %
# 현재 베스트 정확도: 96.10 %
# 총 PROCESSING CYCLE 수: 3,518,038 cycles
# PROCESSING CYCLE / SAMPLE: 351.80 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.59 us
#
# ================= EPOCH 119 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9406, wrong_sample_num: 594, total_inference_sample_num: 10000
# 정확도: 94.06 %
# ...
#
# ================= EPOCH 165 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9598, wrong_sample_num: 402, total_inference_sample_num: 10000
# 정확도: 95.98 %
# 현재 베스트 정확도: 96.17 %
# 총 PROCESSING CYCLE 수: 3,589,119 cycles
# PROCESSING CYCLE / SAMPLE: 358.91 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.95 us
#
# ================= EPOCH 166 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9556, wrong_sample_num: 444, total_inference_sample_num: 10000
# 정확도: 95.56 %
# 현재 베스트 정확도: 96.17 %
# 총 PROCESSING CYCLE 수: 3,594,906 cycles
# PROCESSING CYCLE / SAMPLE: 359.49 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.97 us
#
# ================= EPOCH 167 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9447, wrong_sample_num: 553, total_inference_sample_num: 10000
# 정확도: 94.47 %
# 현재 베스트 정확도: 96.17 %
# 총 PROCESSING CYCLE 수: 3,553,359 cycles
# PROCESSING CYCLE / SAMPLE: 355.34 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.77 us
#
# ================= EPOCH 168 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9503, wrong_sample_num: 497, total_inference_sample_num: 10000
# 정확도: 95.03 %
# 현재 베스트 정확도: 96.17 %
# 총 PROCESSING CYCLE 수: 3,576,171 cycles
# PROCESSING CYCLE / SAMPLE: 357.62 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.88 us
#
# ================= EPOCH 169 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9338, wrong_sample_num: 662, total_inference_sample_num: 10000
# 정확도: 93.38 %
# 현재 베스트 정확도: 96.17 %
# 총 PROCESSING CYCLE 수: 3,597,128 cycles
# PROCESSING CYCLE / SAMPLE: 359.71 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.99 us
#
# ================= EPOCH 170 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9634, wrong_sample_num: 366, total_inference_sample_num: 10000
# 정확도: 96.34 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,624,226 cycles
# PROCESSING CYCLE / SAMPLE: 362.42 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.12 us
#
# ================= EPOCH 171 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9565, wrong_sample_num: 435, total_inference_sample_num: 10000
# 정확도: 95.65 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,643,017 cycles
# PROCESSING CYCLE / SAMPLE: 364.30 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.22 us
#
# ================= EPOCH 172 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9586, wrong_sample_num: 414, total_inference_sample_num: 10000
# 정확도: 95.86 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,670,340 cycles
# PROCESSING CYCLE / SAMPLE: 367.03 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.35 us
#
# ================= EPOCH 173 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9548, wrong_sample_num: 452, total_inference_sample_num: 10000
# 정확도: 95.48 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,632,599 cycles
# PROCESSING CYCLE / SAMPLE: 363.26 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.16 us
#
# ================= EPOCH 174 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9630, wrong_sample_num: 370, total_inference_sample_num: 10000
# 정확도: 96.30 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,633,529 cycles
# PROCESSING CYCLE / SAMPLE: 363.35 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.17 us
#
# ================= EPOCH 175 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9552, wrong_sample_num: 448, total_inference_sample_num: 10000
# 정확도: 95.52 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,721,263 cycles
# PROCESSING CYCLE / SAMPLE: 372.13 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.61 us
#
# ================= EPOCH 176 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9531, wrong_sample_num: 469, total_inference_sample_num: 10000
# 정확도: 95.31 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,650,373 cycles
# PROCESSING CYCLE / SAMPLE: 365.04 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.25 us
#
# ================= EPOCH 177 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9591, wrong_sample_num: 409, total_inference_sample_num: 10000
# 정확도: 95.91 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,666,446 cycles
# PROCESSING CYCLE / SAMPLE: 366.64 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.33 us
#
# ================= EPOCH 178 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9552, wrong_sample_num: 448, total_inference_sample_num: 10000
# 정확도: 95.52 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,709,484 cycles
# PROCESSING CYCLE / SAMPLE: 370.95 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.55 us
#
# ================= EPOCH 179 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9585, wrong_sample_num: 415, total_inference_sample_num: 10000
# 정확도: 95.85 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,655,219 cycles
# PROCESSING CYCLE / SAMPLE: 365.52 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.28 us
#
# ================= EPOCH 180 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9596, wrong_sample_num: 404, total_inference_sample_num: 10000
# 정확도: 95.96 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,743,430 cycles
# PROCESSING CYCLE / SAMPLE: 374.34 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.72 us
#
# ================= EPOCH 181 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9613, wrong_sample_num: 387, total_inference_sample_num: 10000
# 정확도: 96.13 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,664,398 cycles
# PROCESSING CYCLE / SAMPLE: 366.44 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.32 us
#
# ================= EPOCH 182 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9569, wrong_sample_num: 431, total_inference_sample_num: 10000
# 정확도: 95.69 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,660,016 cycles
# PROCESSING CYCLE / SAMPLE: 366.00 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.30 us
#
# ================= EPOCH 183 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9591, wrong_sample_num: 409, total_inference_sample_num: 10000
# 정확도: 95.91 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,604,008 cycles
# PROCESSING CYCLE / SAMPLE: 360.40 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.02 us
#
# ================= EPOCH 184 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9606, wrong_sample_num: 394, total_inference_sample_num: 10000
# 정확도: 96.06 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,727,729 cycles
# PROCESSING CYCLE / SAMPLE: 372.77 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.64 us
#
# ================= EPOCH 185 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9475, wrong_sample_num: 525, total_inference_sample_num: 10000
# 정확도: 94.75 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,493,605 cycles
# PROCESSING CYCLE / SAMPLE: 349.36 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.47 us
#
# ================= EPOCH 186 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9586, wrong_sample_num: 414, total_inference_sample_num: 10000
# 정확도: 95.86 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,594,092 cycles
# PROCESSING CYCLE / SAMPLE: 359.41 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 17.97 us
#
# ================= EPOCH 187 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9451, wrong_sample_num: 549, total_inference_sample_num: 10000
# 정확도: 94.51 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,719,286 cycles
# PROCESSING CYCLE / SAMPLE: 371.93 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.60 us
#
# ================= EPOCH 188 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9500, wrong_sample_num: 500, total_inference_sample_num: 10000
# 정확도: 95.00 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,720,861 cycles
# PROCESSING CYCLE / SAMPLE: 372.09 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.60 us
#
# ================= EPOCH 189 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9573, wrong_sample_num: 427, total_inference_sample_num: 10000
# 정확도: 95.73 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,657,593 cycles
# PROCESSING CYCLE / SAMPLE: 365.76 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.29 us
#
# ================= EPOCH 190 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9493, wrong_sample_num: 507, total_inference_sample_num: 10000
# 정확도: 94.93 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,713,552 cycles
# PROCESSING CYCLE / SAMPLE: 371.36 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.57 us
#
# ================= EPOCH 191 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9465, wrong_sample_num: 535, total_inference_sample_num: 10000
# 정확도: 94.65 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,706,272 cycles
# PROCESSING CYCLE / SAMPLE: 370.63 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.53 us
#
# ================= EPOCH 192 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9528, wrong_sample_num: 472, total_inference_sample_num: 10000
# 정확도: 95.28 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,753,756 cycles
# PROCESSING CYCLE / SAMPLE: 375.38 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.77 us
#
# ================= EPOCH 193 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9607, wrong_sample_num: 393, total_inference_sample_num: 10000
# 정확도: 96.07 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,766,972 cycles
# PROCESSING CYCLE / SAMPLE: 376.70 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.83 us
#
# ================= EPOCH 194 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9533, wrong_sample_num: 467, total_inference_sample_num: 10000
# 정확도: 95.33 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,665,883 cycles
# PROCESSING CYCLE / SAMPLE: 366.59 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.33 us
#
# ================= EPOCH 195 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9593, wrong_sample_num: 407, total_inference_sample_num: 10000
# 정확도: 95.93 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,722,631 cycles
# PROCESSING CYCLE / SAMPLE: 372.26 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.61 us
#
# ================= EPOCH 196 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9541, wrong_sample_num: 459, total_inference_sample_num: 10000
# 정확도: 95.41 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,743,383 cycles
# PROCESSING CYCLE / SAMPLE: 374.34 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.72 us
#
# ================= EPOCH 197 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9584, wrong_sample_num: 416, total_inference_sample_num: 10000
# 정확도: 95.84 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,674,967 cycles
# PROCESSING CYCLE / SAMPLE: 367.50 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.37 us
#
# ================= EPOCH 198 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9597, wrong_sample_num: 403, total_inference_sample_num: 10000
# 정확도: 95.97 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,736,812 cycles
# PROCESSING CYCLE / SAMPLE: 373.68 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.68 us
#
# ================= EPOCH 199 =================
# ######### P_STATE_09_ASIC_INFERENCE_QUEUING mode ######################################################################
# 결과: correct_sample_num: 9573, wrong_sample_num: 427, total_inference_sample_num: 10000
# 정확도: 95.73 %
# 현재 베스트 정확도: 96.34 %
# 총 PROCESSING CYCLE 수: 3,673,075 cycles
# PROCESSING CYCLE / SAMPLE: 367.31 cycles
# ASIC 20MHz라면 샘플 당 걸리는 시간: 18.37 us
# accuracy_list: [91.2, 86.14, 91.60000000000001, 92.12, 91.24, 85.33, 92.82000000000001, 91.32000000000001, 92.89, 91.16, 93.47999999999999, 91.5, 94.15, 93.97999999999999, 92.78, 93.87, 91.64999999999999, 88.44999999999999, 90.56, 94.35, 93.46, 94.81, 94.08, 94.33, 94.71000000000001, 93.02, 94.82000000000001, 94.37, 95.1, 95.57, 94.57, 93.71000000000001, 94.52000000000001, 94.64, 93.72, 95.11, 95.1, 92.60000000000001, 91.71000000000001, 95.45, 93.24, 91.91, 95.41, 94.96, 93.4, 95.16, 93.78, 93.92, 94.19999999999999, 94.77, 94.0, 92.12, 94.71000000000001, 92.64, 94.89, 91.81, 94.44, 95.26, 95.85000000000001, 93.97999999999999, 95.05, 95.21, 94.46, 95.12, 95.22, 95.66, 94.71000000000001, 92.62, 94.54, 93.62, 93.87, 94.93, 93.71000000000001, 94.67, 95.59, 93.60000000000001, 95.23, 95.3, 92.41, 95.73, 94.33, 94.63000000000001, 95.27, 95.39999999999999, 94.69, 94.42, 95.53, 95.1, 94.65, 95.19, 93.99, 93.84, 95.95, 95.57, 94.34, 96.1, 95.59, 94.12, 95.33, 94.84, 95.07, 93.74, 95.72, 95.6, 95.56, 95.7, 95.44, 95.28999999999999, 95.84, 94.32000000000001, 95.28, 91.55, 95.38, 93.37, 94.76, 94.91000000000001, 95.89999999999999, 93.53, 95.22, 94.06, 95.0, 95.05, 93.75, 95.81, 95.74000000000001, 95.75, 95.67, 91.92, 93.42, 95.73, 94.73, 95.95, 93.28999999999999, 95.81, 95.71, 95.57, 96.17, 94.43, 95.41, 95.25, 91.44, 94.82000000000001, 95.97, 95.00999999999999, 95.53, 95.28, 95.30999999999999, 95.76, 95.99, 96.05, 95.43, 95.25, 95.05, 95.8, 94.33, 94.74000000000001, 95.74000000000001, 95.28, 95.89, 94.74000000000001, 94.28999999999999, 95.92, 92.99, 94.62, 95.93, 95.98, 95.56, 94.47, 95.03, 93.38, 96.34, 95.65, 95.86, 95.48, 96.3, 95.52000000000001, 95.30999999999999, 95.91, 95.52000000000001, 95.85000000000001, 95.96000000000001, 96.13000000000001, 95.69, 95.91, 96.06, 94.75, 95.86, 94.51, 95.0, 95.73, 94.93, 94.65, 95.28, 96.07, 95.33, 95.93, 95.41, 95.84, 95.97, 95.73]
# 베스트 정확도: 96.34 % at epoch 170

# %%
# gesture에서 seed0에서 N4에서 weight 0으로 초기화에서
# accuracy_list: [29.166666666666668, 32.5, 28.749999999999996, 29.166666666666668, 35.41666666666667, 36.25, 38.75, 46.666666666666664, 27.500000000000004, 36.666666666666664, 47.91666666666667, 40.416666666666664, 32.083333333333336, 47.91666666666667, 44.583333333333336, 42.916666666666664, 46.25, 41.66666666666667, 54.58333333333333, 40.0, 40.0, 44.166666666666664, 50.83333333333333, 39.166666666666664, 45.0, 44.583333333333336, 22.083333333333332, 31.666666666666664, 41.66666666666667, 36.666666666666664, 38.333333333333336, 41.66666666666667, 39.166666666666664, 40.0, 35.0, 40.833333333333336, 37.083333333333336, 45.416666666666664, 41.66666666666667, 37.083333333333336, 39.58333333333333, 37.916666666666664, 34.583333333333336, 32.083333333333336, 39.166666666666664, 30.0, 42.916666666666664, 32.083333333333336, 38.333333333333336, 48.333333333333336, 27.083333333333332, 49.583333333333336, 45.83333333333333, 38.75, 46.25, 45.0, 41.25, 42.5, 35.833333333333336, 45.416666666666664, 46.25, 46.666666666666664, 44.166666666666664, 46.25, 36.25, 56.25, 47.083333333333336, 37.916666666666664, 50.416666666666664, 35.833333333333336, 39.166666666666664, 43.75, 60.0, 44.166666666666664, 41.25, 40.416666666666664, 38.333333333333336, 41.25, 38.75, 47.91666666666667, 40.833333333333336, 37.083333333333336, 47.91666666666667, 40.416666666666664, 31.25, 38.75, 37.916666666666664, 35.833333333333336, 38.333333333333336, 35.41666666666667, 45.83333333333333, 37.916666666666664, 34.583333333333336, 45.0, 46.666666666666664, 36.666666666666664, 46.25, 41.25, 47.083333333333336, 46.25, 40.833333333333336, 44.583333333333336, 41.25, 43.75, 53.75, 39.166666666666664, 43.333333333333336, 38.333333333333336, 39.58333333333333, 51.24999999999999, 39.58333333333333, 39.58333333333333, 42.916666666666664, 36.25, 44.166666666666664, 41.66666666666667, 43.333333333333336, 44.583333333333336, 47.083333333333336, 39.166666666666664, 41.25, 38.75, 38.333333333333336, 55.00000000000001, 37.083333333333336, 19.166666666666668, 49.583333333333336, 29.583333333333332, 47.91666666666667, 41.66666666666667, 51.24999999999999, 46.25, 42.083333333333336, 42.5, 32.916666666666664, 35.41666666666667, 41.66666666666667, 42.5, 44.583333333333336, 39.166666666666664, 35.0, 48.333333333333336, 45.83333333333333, 52.083333333333336, 36.666666666666664, 36.25, 37.916666666666664, 43.75, 51.66666666666667, 36.25, 42.916666666666664, 52.083333333333336, 27.500000000000004, 37.5, 51.66666666666667, 42.916666666666664, 48.333333333333336, 45.83333333333333, 36.25, 48.75, 40.0, 35.41666666666667, 37.5, 38.75, 37.083333333333336, 48.75, 47.083333333333336, 48.333333333333336, 48.333333333333336, 56.25, 44.166666666666664, 33.75, 55.833333333333336, 42.5, 44.583333333333336, 44.583333333333336, 34.166666666666664, 48.333333333333336, 51.66666666666667, 45.83333333333333, 36.25, 50.83333333333333, 45.83333333333333, 40.416666666666664, 51.24999999999999, 39.166666666666664, 47.5, 37.5, 43.333333333333336, 39.166666666666664, 43.333333333333336, 42.5, 40.833333333333336, 50.83333333333333, 40.833333333333336, 57.08333333333333, 35.41666666666667, 53.75, 39.58333333333333, 42.5]
# 베스트 정확도: 60.00 % at epoch 72
