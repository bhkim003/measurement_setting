# %%
padding = '0'*162

label = '0000'
spike = '0'*378 +'1'*200
timestep5 = (label + spike)*5

one_sample = padding + timestep5
one_sample

hex_output = format(int(one_sample, 2), f'0{len(one_sample)//4}x')
hex_output
# Out:
# '...'

# %%
import os

output_dir = 'zz_measure_dataset/nmnist/test_200spike'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for idx in range(10000):
    file_name = f'nmnist_{idx}.txt'
    output_path = os.path.join(output_dir, f'nmnist_{idx}.txt')


    # 5. 결과 저장
    with open(output_path, 'w') as f:
        f.write(hex_output)
