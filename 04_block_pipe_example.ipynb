# %%
import numpy as np
from mms_ok import XEM7360


def text_transfer(fpga, reorder_str: bool = True):
    from secrets import token_hex

    data = token_hex(32)
    print(f"Data: {data} [{type(data)}]")

    transfer_byte = fpga.WriteToBlockPipeIn(0x80, data, reorder_str=reorder_str)
    print(f"Transfer byte: {transfer_byte} bytes")

    read_data = fpga.ReadFromBlockPipeOut(0xA0, 128 // 8, reorder_str=reorder_str)
    print(f"Read data: {read_data} [{type(read_data)}]")


def array_transfer(fpga):
    data = np.array([i for i in range(1, 16 + 1)], dtype=np.uint8)
    print(f"Data: {data} [{type(data)}]")

    transfer_byte = fpga.WriteToBlockPipeIn(0x80, data, reorder_str=False)
    print(f"Transfer byte: {transfer_byte} bytes")

    read_data = fpga.ReadFromBlockPipeOut(0xA0, 16, reorder_str=False)
    print(f"Read data: {read_data} [{type(read_data)}]")
    print(
        f"Read data: {read_data.to_ndarray(np.uint8)} [{type(read_data.to_ndarray(np.uint8))}]"
    )


def main():
    bitstream_path = r"bitstream/block_pipe_example.bit"

    with XEM7360(bitstream_path=bitstream_path) as fpga:
        fpga.reset()

        text_transfer(fpga, reorder_str=True)
        # array_transfer(fpga)


if __name__ == "__main__":
    main()
# Out:
# 2026-01-21 17:50:15.563 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:28 - FrontPanel SDK Version: 5.3.6
# 2026-01-21 17:50:15.567 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:39 - FrontPanel API ready
# 2026-01-21 17:50:15.794 | INFO     | mms_ok.fpga:_validate_bitstream_path:117 - Bitstream file: c:\Users\User\measurement_setting\bitstream\block_pipe_example.bit
# 2026-01-21 17:50:15.795 | INFO     | mms_ok.fpga:_validate_bitstream_path:120 - Bitstream date: 2025-04-07 15:29:05
# 2026-01-21 17:50:15.800 | INFO     | mms_ok.fpga:_connect:147 - Model        : XEM7360-K160T
# 2026-01-21 17:50:15.800 | INFO     | mms_ok.fpga:_connect:148 - Serial Number: 2420001BL5
# 2026-01-21 17:50:15.800 | INFO     | mms_ok.fpga:_connect:149 - Interface    : USB 3
# 2026-01-21 17:50:15.801 | INFO     | mms_ok.fpga:_connect:150 - USB Speed    : SUPER
# 2026-01-21 17:50:15.801 | INFO     | mms_ok.fpga:_connect:151 - Max Blocksize: 16384
# 2026-01-21 17:50:15.801 | INFO     | mms_ok.fpga:_connect:152 - Wire Width   : 32
# 2026-01-21 17:50:15.802 | INFO     | mms_ok.fpga:_connect:153 - Trigger Width: 32
# 2026-01-21 17:50:15.802 | INFO     | mms_ok.fpga:_connect:154 - Pipe Width   : 32
# 2026-01-21 17:50:15.935 | INFO     | mms_ok.fpga:_configure:172 - Input bitstream file: "block_pipe_example.bit" is connected to the device!
# 2026-01-21 17:50:15.936 | INFO     | mms_ok.fpga:_configure:184 - FrontPanel is enabled!
# 2026-01-21 17:50:15.937 | INFO     | mms_ok.fpga:_check_device_settings:703 - Please check the I/O voltage settings.
# 2026-01-21 17:50:15.937 | INFO     | mms_ok.fpga:_check_device_settings:704 - Bank 12 Voltage: 180 mV
# 2026-01-21 17:50:15.937 | INFO     | mms_ok.fpga:_check_device_settings:705 - Bank 15 Voltage: 180 mV
# 2026-01-21 17:50:15.938 | INFO     | mms_ok.fpga:_check_device_settings:706 - Bank 16 Voltage: 180 mV
# 2026-01-21 17:50:15.938 | INFO     | mms_ok.fpga:_check_device_settings:707 - Bank 32 Voltage: 180 mV
# 2026-01-21 17:50:15.939 | INFO     | mms_ok.fpga:__init__:85 - AutoWireIn is enabled!
# 2026-01-21 17:50:15.939 | INFO     | mms_ok.fpga:__init__:86 - AutoWireOut is enabled!
# 2026-01-21 17:50:15.939 | INFO     | mms_ok.fpga:__init__:89 - AutoTriggerOut is enabled!
# 2026-01-21 17:50:15.940 | INFO     | mms_ok.fpga:__init__:92 - FPGA initialized!
#
# 2026-01-21 17:50:15.940 | INFO     | mms_ok.fpga:reset:264 - Reset Start (1.0s)
# 2026-01-21 17:50:16.946 | INFO     | mms_ok.fpga:reset:272 - Reset End (1.0s)
#
# 2026-01-21 17:50:16.947 | INFO     | mms_ok.fpga:__exit__:236 - Closing device
# 2026-01-21 17:50:16.948 | INFO     | mms_ok.fpga:__exit__:241 - Device closed!
# Data: cfd6061c624d831748bbbd7fab0b62a7f9665df8c4b69d722a55ed4674817fd8 [<class 'str'>]
# Transfer byte: 32 bytes
# Read data: F9665DF8C4B69D722A55ED4674817FD8 [<class 'mms_ok.pipeoutdata.PipeOutData'>]
