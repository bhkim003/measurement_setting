# %%
import numpy as np
from mms_ok import XEM7310
# Out:
# 2025-12-30 22:08:36.487 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:28 - FrontPanel SDK Version: 5.3.6
# 2025-12-30 22:08:36.500 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:39 - FrontPanel API ready

# %%
def main():
    bitstream_path = r"bitstream/trigger_example.bit"

    with XEM7310(bitstream_path=bitstream_path) as fpga:
        fpga.reset()

        data = np.random.randint(0, 2**13, size=8, dtype=np.uint16)
        print(f"Data: {data}")
        ans = np.sum(data)
        print(f"Answer: {ans}")

        fpga.WriteToPipeIn(0x80, data)

        fpga.ActivateTriggerIn(0x40, 0)
        print("Triggered!")

        fpga.CheckTriggered(0x60, 0x1, timeout=1)

        read_data = fpga.ReadFromPipeOut(0xA0, 16).to_ndarray(np.uint16)
        print(f"Read data: {read_data[-2]} | Answer: {ans}")


if __name__ == "__main__":
    main()
# Out:
# 2025-12-30 22:08:36.673 | INFO     | mms_ok.fpga:_validate_bitstream_path:117 - Bitstream file: c:\Users\User\measurement_setting\bitstream\trigger_example.bit
# 2025-12-30 22:08:36.673 | INFO     | mms_ok.fpga:_validate_bitstream_path:120 - Bitstream date: 2025-04-07 15:00:26
# 2025-12-30 22:08:36.679 | INFO     | mms_ok.fpga:_connect:147 - Model        : XEM7310-A75
# 2025-12-30 22:08:36.680 | INFO     | mms_ok.fpga:_connect:148 - Serial Number: 1917000Q6P
# 2025-12-30 22:08:36.680 | INFO     | mms_ok.fpga:_connect:149 - Interface    : USB 3
# 2025-12-30 22:08:36.681 | INFO     | mms_ok.fpga:_connect:150 - USB Speed    : SUPER
# 2025-12-30 22:08:36.681 | INFO     | mms_ok.fpga:_connect:151 - Max Blocksize: 16384
# 2025-12-30 22:08:36.681 | INFO     | mms_ok.fpga:_connect:152 - Wire Width   : 32
# 2025-12-30 22:08:36.682 | INFO     | mms_ok.fpga:_connect:153 - Trigger Width: 32
# 2025-12-30 22:08:36.682 | INFO     | mms_ok.fpga:_connect:154 - Pipe Width   : 32
# 2025-12-30 22:08:36.798 | INFO     | mms_ok.fpga:_configure:172 - Input bitstream file: "trigger_example.bit" is connected to the device!
# 2025-12-30 22:08:36.799 | INFO     | mms_ok.fpga:_configure:184 - FrontPanel is enabled!
# 2025-12-30 22:08:36.799 | INFO     | mms_ok.fpga:__init__:85 - AutoWireIn is enabled!
# 2025-12-30 22:08:36.800 | INFO     | mms_ok.fpga:__init__:86 - AutoWireOut is enabled!
# 2025-12-30 22:08:36.800 | INFO     | mms_ok.fpga:__init__:89 - AutoTriggerOut is enabled!
# 2025-12-30 22:08:36.800 | INFO     | mms_ok.fpga:__init__:92 - FPGA initialized!
#
# 2025-12-30 22:08:36.801 | INFO     | mms_ok.fpga:reset:264 - Reset Start (1.0s)
# 2025-12-30 22:08:37.807 | INFO     | mms_ok.fpga:reset:272 - Reset End (1.0s)
#
# 2025-12-30 22:08:37.809 | INFO     | mms_ok.fpga:__exit__:236 - Closing device
# 2025-12-30 22:08:37.809 | INFO     | mms_ok.fpga:__exit__:241 - Device closed!
# Data: [6578 2686 5176 2086 5140 4402 4512 7897]
# Answer: 38477
# Triggered!
# Read data: 38477 | Answer: 38477
