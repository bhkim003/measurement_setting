# %%
import numpy as np
from mms_ok import XEM7360


def main():
    bitstream_path = r"bitstream/trigger_example.bit"

    with XEM7360(bitstream_path=bitstream_path) as fpga:
        fpga.reset()

        data = np.random.randint(0, 2**13, size=8, dtype=np.uint16)
        print(f"Data: {data}")
        ans = np.sum(data)
        print(f"Answer: {ans}")

        fpga.WriteToPipeIn(0x80, data)

        fpga.ActivateTriggerIn(0x40, 0)
        print("Triggered!")

        fpga.CheckTriggered(0x60, 0x1, timeout=1)

        read_data = fpga.ReadFromPipeOut(0xA0, 16).to_ndarray(np.uint16)
        print(f"Read data: {read_data[-2]} | Answer: {ans}")


if __name__ == "__main__":
    main()
# Out:
# 2026-01-21 17:51:42.748 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:28 - FrontPanel SDK Version: 5.3.6
# 2026-01-21 17:51:42.751 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:39 - FrontPanel API ready
# 2026-01-21 17:51:42.958 | INFO     | mms_ok.fpga:_validate_bitstream_path:117 - Bitstream file: c:\Users\User\measurement_setting\bitstream\trigger_example.bit
# 2026-01-21 17:51:42.958 | INFO     | mms_ok.fpga:_validate_bitstream_path:120 - Bitstream date: 2025-04-07 15:29:05
# 2026-01-21 17:51:42.964 | INFO     | mms_ok.fpga:_connect:147 - Model        : XEM7360-K160T
# 2026-01-21 17:51:42.964 | INFO     | mms_ok.fpga:_connect:148 - Serial Number: 2420001BL5
# 2026-01-21 17:51:42.964 | INFO     | mms_ok.fpga:_connect:149 - Interface    : USB 3
# 2026-01-21 17:51:42.965 | INFO     | mms_ok.fpga:_connect:150 - USB Speed    : SUPER
# 2026-01-21 17:51:42.966 | INFO     | mms_ok.fpga:_connect:151 - Max Blocksize: 16384
# 2026-01-21 17:51:42.966 | INFO     | mms_ok.fpga:_connect:152 - Wire Width   : 32
# 2026-01-21 17:51:42.966 | INFO     | mms_ok.fpga:_connect:153 - Trigger Width: 32
# 2026-01-21 17:51:42.967 | INFO     | mms_ok.fpga:_connect:154 - Pipe Width   : 32
# 2026-01-21 17:51:43.110 | INFO     | mms_ok.fpga:_configure:172 - Input bitstream file: "trigger_example.bit" is connected to the device!
# 2026-01-21 17:51:43.111 | INFO     | mms_ok.fpga:_configure:184 - FrontPanel is enabled!
# 2026-01-21 17:51:43.112 | INFO     | mms_ok.fpga:_check_device_settings:703 - Please check the I/O voltage settings.
# 2026-01-21 17:51:43.112 | INFO     | mms_ok.fpga:_check_device_settings:704 - Bank 12 Voltage: 180 mV
# 2026-01-21 17:51:43.113 | INFO     | mms_ok.fpga:_check_device_settings:705 - Bank 15 Voltage: 180 mV
# 2026-01-21 17:51:43.113 | INFO     | mms_ok.fpga:_check_device_settings:706 - Bank 16 Voltage: 180 mV
# 2026-01-21 17:51:43.113 | INFO     | mms_ok.fpga:_check_device_settings:707 - Bank 32 Voltage: 180 mV
# 2026-01-21 17:51:43.114 | INFO     | mms_ok.fpga:__init__:85 - AutoWireIn is enabled!
# 2026-01-21 17:51:43.114 | INFO     | mms_ok.fpga:__init__:86 - AutoWireOut is enabled!
# 2026-01-21 17:51:43.115 | INFO     | mms_ok.fpga:__init__:89 - AutoTriggerOut is enabled!
# 2026-01-21 17:51:43.115 | INFO     | mms_ok.fpga:__init__:92 - FPGA initialized!
#
# 2026-01-21 17:51:43.115 | INFO     | mms_ok.fpga:reset:264 - Reset Start (1.0s)
# 2026-01-21 17:51:44.123 | INFO     | mms_ok.fpga:reset:272 - Reset End (1.0s)
#
# 2026-01-21 17:51:44.125 | INFO     | mms_ok.fpga:__exit__:236 - Closing device
# 2026-01-21 17:51:44.126 | INFO     | mms_ok.fpga:__exit__:241 - Device closed!
# Data: [2558 7100 7831 5460 7751 7976 4557  135]
# Answer: 43368
# Triggered!
# Read data: 43368 | Answer: 43368
