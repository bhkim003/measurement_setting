# %%
import numpy as np
from mms_ok import XEM7360


def main():
    bitstream_path = r"bitstream/wire_example.bit"

    with XEM7360(bitstream_path=bitstream_path) as fpga:
        data0 = np.random.randint(0, 2**4)
        data1 = np.random.randint(0, 2**4)

        OP_AND = 0
        OP_OR = 1

        op_select = OP_AND

        op_result = (data0 | data1) if op_select == OP_OR else (data0 & data1)

        print(f"=== SW Result ===")
        print(f"data0     : {np.binary_repr(data0, width=4)}")
        print(f"data1     : {np.binary_repr(data1, width=4)}")
        print(f"op        : {'OR' if op_select == OP_OR else 'AND'}")
        print(f"op_result : {np.binary_repr(op_result, width=4)}")

        fpga.SetWireInValue(0x00, data0)
        fpga.SetWireInValue(0x01, data1)
        fpga.SetWireInValue(0x02, op_select)

        or_result = fpga.GetWireOutValue(0x20)
        and_result = fpga.GetWireOutValue(0x21)

        print(f"=== HW Result ===")
        print(f"OR  result: {np.binary_repr(or_result, width=4)}")
        print(f"AND result: {np.binary_repr(and_result, width=4)}")
        print()


if __name__ == "__main__":
    main()
# Out:
# 2026-01-21 17:49:09.085 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:28 - FrontPanel SDK Version: 5.3.6
# 2026-01-21 17:49:09.089 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:39 - FrontPanel API ready
# 2026-01-21 17:49:09.304 | INFO     | mms_ok.fpga:_validate_bitstream_path:117 - Bitstream file: c:\Users\User\measurement_setting\bitstream\wire_example.bit
# 2026-01-21 17:49:09.305 | INFO     | mms_ok.fpga:_validate_bitstream_path:120 - Bitstream date: 2025-04-07 15:29:05
# 2026-01-21 17:49:09.310 | INFO     | mms_ok.fpga:_connect:147 - Model        : XEM7360-K160T
# 2026-01-21 17:49:09.310 | INFO     | mms_ok.fpga:_connect:148 - Serial Number: 2420001BL5
# 2026-01-21 17:49:09.311 | INFO     | mms_ok.fpga:_connect:149 - Interface    : USB 3
# 2026-01-21 17:49:09.311 | INFO     | mms_ok.fpga:_connect:150 - USB Speed    : SUPER
# 2026-01-21 17:49:09.312 | INFO     | mms_ok.fpga:_connect:151 - Max Blocksize: 16384
# 2026-01-21 17:49:09.312 | INFO     | mms_ok.fpga:_connect:152 - Wire Width   : 32
# 2026-01-21 17:49:09.312 | INFO     | mms_ok.fpga:_connect:153 - Trigger Width: 32
# 2026-01-21 17:49:09.313 | INFO     | mms_ok.fpga:_connect:154 - Pipe Width   : 32
# 2026-01-21 17:49:09.446 | INFO     | mms_ok.fpga:_configure:172 - Input bitstream file: "wire_example.bit" is connected to the device!
# 2026-01-21 17:49:09.447 | INFO     | mms_ok.fpga:_configure:184 - FrontPanel is enabled!
# 2026-01-21 17:49:09.448 | INFO     | mms_ok.fpga:_check_device_settings:703 - Please check the I/O voltage settings.
# 2026-01-21 17:49:09.448 | INFO     | mms_ok.fpga:_check_device_settings:704 - Bank 12 Voltage: 180 mV
# 2026-01-21 17:49:09.449 | INFO     | mms_ok.fpga:_check_device_settings:705 - Bank 15 Voltage: 180 mV
# 2026-01-21 17:49:09.449 | INFO     | mms_ok.fpga:_check_device_settings:706 - Bank 16 Voltage: 180 mV
# 2026-01-21 17:49:09.449 | INFO     | mms_ok.fpga:_check_device_settings:707 - Bank 32 Voltage: 180 mV
# 2026-01-21 17:49:09.450 | INFO     | mms_ok.fpga:__init__:85 - AutoWireIn is enabled!
# 2026-01-21 17:49:09.450 | INFO     | mms_ok.fpga:__init__:86 - AutoWireOut is enabled!
# 2026-01-21 17:49:09.451 | INFO     | mms_ok.fpga:__init__:89 - AutoTriggerOut is enabled!
# 2026-01-21 17:49:09.451 | INFO     | mms_ok.fpga:__init__:92 - FPGA initialized!
#
# 2026-01-21 17:49:09.453 | INFO     | mms_ok.fpga:__exit__:236 - Closing device
# 2026-01-21 17:49:09.454 | INFO     | mms_ok.fpga:__exit__:241 - Device closed!
# === SW Result ===
# data0     : 0001
# data1     : 1001
# op        : AND
# op_result : 0001
# === HW Result ===
# OR  result: 1001
# AND result: 0001
