# %%
import numpy as np
from mms_ok import XEM7310
# Out:
# 2025-12-30 15:39:56.754 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:28 - FrontPanel SDK Version: 5.3.6
# 2025-12-30 15:39:56.754 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:39 - FrontPanel API ready

# %%
def main():
    bitstream_path = r"bitstream/wire_example.bit"

    with XEM7310(bitstream_path=bitstream_path) as fpga:
        data0 = np.random.randint(0, 2**8)
        data1 = np.random.randint(0, 2**8)

        OP_AND = 0
        OP_OR = 1

        op_select = OP_OR

        op_result = (data0 | data1) if op_select == OP_OR else (data0 & data1)

        print(f"=== SW Result ===")
        print(f"data0     : {np.binary_repr(data0, width=8)}")
        print(f"data1     : {np.binary_repr(data1, width=8)}")
        print(f"op        : {'OR' if op_select == OP_OR else 'AND'}")
        print(f"op_result : {np.binary_repr(op_result, width=8)}")

        fpga.SetWireInValue(0x00, data0)
        fpga.SetWireInValue(0x01, data1)
        fpga.SetWireInValue(0x02, op_select)

        or_result = fpga.GetWireOutValue(0x20)
        and_result = fpga.GetWireOutValue(0x21)

        print(f"=== HW Result ===")
        print(f"OR  result: {np.binary_repr(or_result, width=8)}")
        print(f"AND result: {np.binary_repr(and_result, width=8)}")
        print()


if __name__ == "__main__":
    main()
# Out:
# 2025-12-30 15:39:56.926 | INFO     | mms_ok.fpga:_validate_bitstream_path:117 - Bitstream file: c:\Users\User\measurement_setting\bitstream\wire_example.bit
# 2025-12-30 15:39:56.927 | INFO     | mms_ok.fpga:_validate_bitstream_path:120 - Bitstream date: 2025-04-07 15:00:26
# 2025-12-30 15:39:56.933 | INFO     | mms_ok.fpga:_connect:147 - Model        : XEM7310-A75
# 2025-12-30 15:39:56.934 | INFO     | mms_ok.fpga:_connect:148 - Serial Number: 1739000JB2
# 2025-12-30 15:39:56.934 | INFO     | mms_ok.fpga:_connect:149 - Interface    : USB 3
# 2025-12-30 15:39:56.934 | INFO     | mms_ok.fpga:_connect:150 - USB Speed    : SUPER
# 2025-12-30 15:39:56.935 | INFO     | mms_ok.fpga:_connect:151 - Max Blocksize: 16384
# 2025-12-30 15:39:56.935 | INFO     | mms_ok.fpga:_connect:152 - Wire Width   : 32
# 2025-12-30 15:39:56.935 | INFO     | mms_ok.fpga:_connect:153 - Trigger Width: 32
# 2025-12-30 15:39:56.935 | INFO     | mms_ok.fpga:_connect:154 - Pipe Width   : 32
# 2025-12-30 15:39:57.047 | INFO     | mms_ok.fpga:_configure:172 - Input bitstream file: "wire_example.bit" is connected to the device!
# 2025-12-30 15:39:57.048 | INFO     | mms_ok.fpga:_configure:184 - FrontPanel is enabled!
# 2025-12-30 15:39:57.048 | INFO     | mms_ok.fpga:__init__:85 - AutoWireIn is enabled!
# 2025-12-30 15:39:57.049 | INFO     | mms_ok.fpga:__init__:86 - AutoWireOut is enabled!
# 2025-12-30 15:39:57.049 | INFO     | mms_ok.fpga:__init__:89 - AutoTriggerOut is enabled!
# 2025-12-30 15:39:57.050 | INFO     | mms_ok.fpga:__init__:92 - FPGA initialized!
#
# 2025-12-30 15:39:57.052 | INFO     | mms_ok.fpga:__exit__:236 - Closing device
# 2025-12-30 15:39:57.052 | INFO     | mms_ok.fpga:__exit__:241 - Device closed!
# === SW Result ===
# data0     : 10011101
# data1     : 00100111
# op        : OR
# op_result : 10111111
# === HW Result ===
# OR  result: 10111111
# AND result: 00000101
