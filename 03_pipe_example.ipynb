# %%
import numpy as np
from mms_ok import XEM7310
# Out:
# 2025-12-30 21:27:06.245 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:28 - FrontPanel SDK Version: 5.3.6
# 2025-12-30 21:27:06.249 | INFO     | mms_ok.ok_setup:copy_frontpanel_files:39 - FrontPanel API ready

# %%
def text_transfer(fpga, reorder_str: bool = True):
    from secrets import token_hex

    data = token_hex(16)
    print(f"Data: {data} [{type(data)}]")

    transfer_byte = fpga.WriteToPipeIn(0x80, data, reorder_str=reorder_str)
    print(f"Transfer byte: {transfer_byte} bytes")

    read_data = fpga.ReadFromPipeOut(0xA0, 128 // 8, reorder_str=reorder_str)
    print(f"Read data: {read_data} [{type(read_data)}]")


def array_transfer(fpga):
    data = np.array([i for i in range(1, 16 + 1)], dtype=np.uint8)
    print(f"Data: {data} [{type(data)}]")

    transfer_byte = fpga.WriteToPipeIn(0x80, data)
    print(f"Transfer byte: {transfer_byte} bytes")

    read_data = fpga.ReadFromPipeOut(0xA0, 16)
    print(f"Read data: {read_data} [{type(read_data)}]")
    print(
        f"Read data: {read_data.to_ndarray(np.uint8)} [{type(read_data.to_ndarray(np.uint8))}]"
    )


def main():
    bitstream_path = r"bitstream/pipe_example.bit"

    with XEM7310(bitstream_path=bitstream_path) as fpga:
        fpga.reset()

        text_transfer(fpga, reorder_str=True)
        # array_transfer(fpga)


if __name__ == "__main__":
    main()
# Out:
# 2025-12-30 21:27:06.412 | INFO     | mms_ok.fpga:_validate_bitstream_path:117 - Bitstream file: c:\Users\User\measurement_setting\bitstream\pipe_example.bit
# 2025-12-30 21:27:06.412 | INFO     | mms_ok.fpga:_validate_bitstream_path:120 - Bitstream date: 2025-04-07 15:00:26
# 2025-12-30 21:27:06.424 | INFO     | mms_ok.fpga:_connect:147 - Model        : XEM7310-A75
# 2025-12-30 21:27:06.424 | INFO     | mms_ok.fpga:_connect:148 - Serial Number: 1917000Q6P
# 2025-12-30 21:27:06.424 | INFO     | mms_ok.fpga:_connect:149 - Interface    : USB 3
# 2025-12-30 21:27:06.424 | INFO     | mms_ok.fpga:_connect:150 - USB Speed    : SUPER
# 2025-12-30 21:27:06.424 | INFO     | mms_ok.fpga:_connect:151 - Max Blocksize: 16384
# 2025-12-30 21:27:06.427 | INFO     | mms_ok.fpga:_connect:152 - Wire Width   : 32
# 2025-12-30 21:27:06.427 | INFO     | mms_ok.fpga:_connect:153 - Trigger Width: 32
# 2025-12-30 21:27:06.427 | INFO     | mms_ok.fpga:_connect:154 - Pipe Width   : 32
# 2025-12-30 21:27:06.544 | INFO     | mms_ok.fpga:_configure:172 - Input bitstream file: "pipe_example.bit" is connected to the device!
# 2025-12-30 21:27:06.544 | INFO     | mms_ok.fpga:_configure:184 - FrontPanel is enabled!
# 2025-12-30 21:27:06.544 | INFO     | mms_ok.fpga:__init__:85 - AutoWireIn is enabled!
# 2025-12-30 21:27:06.544 | INFO     | mms_ok.fpga:__init__:86 - AutoWireOut is enabled!
# 2025-12-30 21:27:06.544 | INFO     | mms_ok.fpga:__init__:89 - AutoTriggerOut is enabled!
# 2025-12-30 21:27:06.544 | INFO     | mms_ok.fpga:__init__:92 - FPGA initialized!
#
# 2025-12-30 21:27:06.544 | INFO     | mms_ok.fpga:reset:264 - Reset Start (1.0s)
# 2025-12-30 21:27:07.549 | INFO     | mms_ok.fpga:reset:272 - Reset End (1.0s)
#
# 2025-12-30 21:27:07.549 | INFO     | mms_ok.fpga:__exit__:236 - Closing device
# 2025-12-30 21:27:07.549 | INFO     | mms_ok.fpga:__exit__:241 - Device closed!
# Data: b1f69b765925e390ac995a9737800d9b [<class 'str'>]
# Transfer byte: 16 bytes
# Read data: B1F69B765925E390AC995A9737800D9B [<class 'mms_ok.pipeoutdata.PipeOutData'>]
